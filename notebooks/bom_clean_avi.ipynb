# %%
import pandas as pd

# %%
import requests
page = requests.get('https://www.boxofficemojo.com/year/2018/?grossesOption=totalGrosses&sortDir=asc&sort=releaseDate&ref_=bo_yld__resort')
page2 = requests.get('https://www.boxofficemojo.com/year/2019/?grossesOption=totalGrosses&sortDir=asc&sort=releaseDate&ref_=bo_yld__resort')
page2
# Out:
# <Response [200]>

# %%
page2.status_code
# Out:
# 200

# %%
page2.content
# Out:
# b'<!doctype html><html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1.0" />\n                <meta charset="utf-8" />\n            <title dir="ltr">Domestic Box Office For 2019 - Box Office Mojo</title><meta content="Domestic Box Office For 2019" name="title" />\n            <meta content="Box Office Mojo" property="og:site_name" />\n            <meta content="https://m.media-amazon.com/images/G/01/boxofficemojo/logo/mojo-logo-bg.png" property="og:image"/>\n            <meta name="format-detection" content="telephone=no" />\n            <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" type="image/x-icon" rel="icon" />\n            <link rel="canonical" href="https://www.boxofficemojo.com/year/2019/?grossesOption=totalGrosses&sort=releaseDate&sortDir=asc" />\n            <link rel="stylesheet" href="https://images-na.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|01ZTHTZObnL.css,41DAFIecsVL.css,51IB+wfP8qL.css,01ZfXnjPmmL.css,01oDR3IULNL.css,01Vctty9pOL.css,31ZcpBfSgNL.css,01XPHJk60-L.css,21qPwhPKAAL.css,01R0k0yxPXL.css,21xVR0NtxzL.css,11gneA3MtJL.css,21fecG8pUzL.css,01RddH8vm-L.css,01CFUgsA-YL.css,21AmhU6t0sL.css,11zGrJZ9D2L.css,11tRp6+0HHL.css,11061HxnEvL.css,11oHt2HYxnL.css,01-fWz3sOQL.css,11ocrgKoE-L.css,11RKoGSb-gL.css,11g1xm90ZvL.css,01QrWuRrZ-L.css,21pIv-yKhaL.css,01Wiow6micL.css,01gAR5pB+IL.css,119dKrtBoVL.css,11Y05DTEL6L.css,01cbS3UK11L.css,21F85am0yFL.css,01giMEP+djL.css_.css?AUIClients/AmazonUI#us.not-trident" />\n<link rel="stylesheet" href="https://images-na.ssl-images-amazon.com/images/I/51e2aUsLp9L.css?AUIClients/IMDbMojoSiteAssets" />\n<script>\n(function(f,h,Q,E){function F(a){u&&u.tag&&u.tag(q(":","aui",a))}function v(a,b){u&&u.count&&u.count("aui:"+a,0===b?0:b||(u.count("aui:"+a)||0)+1)}function m(a){try{return a.test(navigator.userAgent)}catch(b){return!1}}function x(a,b,c){a.addEventListener?a.addEventListener(b,c,!1):a.attachEvent&&a.attachEvent("on"+b,c)}function q(a,b,c,e){b=b&&c?b+a+c:b||c;return e?q(a,b,e):b}function G(a,b,c){try{Object.defineProperty(a,b,{value:c,writable:!1})}catch(e){a[b]=c}return c}function ta(a,b){var c=a.length,\ne=c,g=function(){e--||(R.push(b),S||(setTimeout(ca,0),S=!0))};for(g();c--;)da[a[c]]?g():(z[a[c]]=z[a[c]]||[]).push(g)}function ua(a,b,c,e,g){var d=h.createElement(a?"script":"link");x(d,"error",e);g&&x(d,"load",g);a?(d.type="text/javascript",d.async=!0,c&&/AUIClients|images[/]I/.test(b)&&d.setAttribute("crossorigin","anonymous"),d.src=b):(d.rel="stylesheet",d.href=b);h.getElementsByTagName("head")[0].appendChild(d)}function ea(a,b){return function(c,e){function g(){ua(b,c,d,function(b){T?v("resource_unload"):\nd?(d=!1,v("resource_retry"),g()):(v("resource_error"),a.log("Asset failed to load: "+c));b&&b.stopPropagation?b.stopPropagation():f.event&&(f.event.cancelBubble=!0)},e)}if(fa[c])return!1;fa[c]=!0;v("resource_count");var d=!0;return!g()}}function va(a,b,c){for(var e={name:a,guard:function(c){return b.guardFatal(a,c)},guardTime:function(a){return b.guardTime(a)},logError:function(c,d,e){b.logError(c,d,e,a)}},g=[],d=0;d<c.length;d++)H.hasOwnProperty(c[d])&&(g[d]=U.hasOwnProperty(c[d])?U[c[d]](H[c[d]],\ne):H[c[d]]);return g}function A(a,b,c,e,g){return function(d,h){function n(){var a=null;e?a=h:"function"===typeof h&&(p.start=w(),a=h.apply(f,va(d,k,l)),p.end=w());if(b){H[d]=a;a=d;for(da[a]=!0;(z[a]||[]).length;)z[a].shift()();delete z[a]}p.done=!0}var k=g||this;"function"===typeof d&&(h=d,d=E);b&&(d=d?d.replace(ha,""):"__NONAME__",V.hasOwnProperty(d)&&k.error(q(", reregistered by ",q(" by ",d+" already registered",V[d]),k.attribution),d),V[d]=k.attribution);for(var l=[],m=0;m<a.length;m++)l[m]=\na[m].replace(ha,"");var p=B[d||"anon"+ ++wa]={depend:l,registered:w(),namespace:k.namespace};c?n():ta(l,k.guardFatal(d,n));return{decorate:function(a){U[d]=k.guardFatal(d,a)}}}}function ia ...

# %%
from bs4 import BeautifulSoup as BS
url = "https://www.boxofficemojo.com/year/2018/?sort=gross&ref_=bo_yld__resort#table"
page=requests.get(url)
soup = BS(page.content, 'html.parser')

# %%
url2 = "https://www.boxofficemojo.com/year/2019/?sort=gross&ref_=bo_yld__resort#table"
page2=requests.get(url2)
soup2 = BS(page2.content, 'html.parser')

# %%
titles = soup.find_all(class_='a-text-left mojo-field-type-release mojo-cell-wide')

# %%
titles2 = soup2.find_all(class_='a-text-left mojo-field-type-release mojo-cell-wide')

# %%
titles[1].select('a')[0].string
# Out:
# 'Avengers: Infinity War'

# %%
titles2[1].select('a')[0].string
# Out:
# 'The Lion King'

# %%
titles[0].select('a')[0].string
# Out:
# 'Black Panther'

# %%
all_titles = []
for title in titles:
    all_titles.append(title.select('a')[0].string)
all_titles
# Out:
# ['Black Panther',
#  'Avengers: Infinity War',
#  'Incredibles 2',
#  'Jurassic World: Fallen Kingdom',
#  'Deadpool 2',
#  'The Grinch',
#  'Jumanji: Welcome to the Jungle',
#  'Mission: Impossible - Fallout',
#  'Ant-Man and the Wasp',
#  'Solo: A Star Wars Story',
#  'Venom',
#  'A Star Is Born',
#  'Aquaman',
#  'Bohemian Rhapsody',
#  'A Quiet Place',
#  'Ralph Breaks the Internet',
#  'Crazy Rich Asians',
#  'Hotel Transylvania 3: Summer Vacation',
#  'Halloween',
#  'Fantastic Beasts: The Crimes of Grindelwald',
#  'The Meg',
#  "Ocean's Eight",
#  'Ready Player One',
#  'The Greatest Showman',
#  'Mamma Mia! Here We Go Again',
#  'The Nun',
#  'Peter Rabbit',
#  'Creed II',
#  'Spider-Man: Into the Spider-Verse',
#  'Mary Poppins Returns',
#  'Star Wars: Episode VIII - The Last Jedi',
#  'The Equalizer 2',
#  'Rampage',
#  'A Wrinkle in Time',
#  'Fifty Shades Freed',
#  'Christopher Robin',
#  'I Can Only Imagine',
#  'Smallfoot',
#  'The Post',
#  'Night School',
#  'Bumblebee',
#  'The First Purge',
#  'Game Night',
#  'Book Club',
#  'The House with a Clock in Its Walls',
#  'Skyscraper',
#  'Insidious: The Last Key',
#  'Instant Family',
#  'The Mule',
#  'Blockers',
#  'Pacific Rim: Uprising',
#  'Tomb Raider',
#  'Maze Runner: The Death Cure',
#  'Tag',
#  'The Nutcracker and the Four Realms',
#  'A Simple Favor',
#  'Life of the Party',
#  'The Predator',
#  'Overboard',
#  'Sicario: Day of the Soldado',
#  'I Feel Pretty',
#  'BlacKkKlansman',
#  'The Shape of Water',
#  'Red Sparrow',
#  'Breaking In',
#  'Goosebumps 2: Haunted Halloween',
#  '12 Strong',
#  'Den of Thieves',
#  'First Man',
#  'Hereditary',
#  'Acrimony',
#  'Sherlock Gnomes',
#  'Uncle Drew',
#  'Widows',
#  'Pitch Perfect 3',
#  'Truth or Dare',
#  'Paddington 2',
#  'Love, Simon',
#  'Darkest Hour',
#  'The Commuter',
#  'The 15:17 to Paris',
#  'Mile 22',
#  'Alpha',
#  'Peppermint',
#  'Death Wish',
#  'The Spy Who Dumped Me',
#  'Annihilation',
#  'Green Book',
#  'Isle of Dogs',
#  "Nobody's Fool",
#  'Adrift',
#  'Ferdinand',
#  'Robin Hood',
#  'Super Troopers 2',
#  'Slender Man',
#  'Three Billboards Outside Ebbing, Missouri',
#  'Coco',
#  'Teen Titans GO! To the Movies',
#  'Hostiles',
#  'The Hate U Give',
#  'I, Tonya',
#  'Searching',
#  'Winchester',
#  'The Strangers: Prey at Night',
#  'White Boy Rick',
#  'Second Act',
#  "Molly's Game",
#  "Won't You Be My Neighbor?",
#  'Overlord',
#  'Holmes & Watson',
#  'Proud Mary',
#  'The Happytime Murders',
#  'Phantom Thread',
#  'SuperFly',
#  'Vice',
#  'Show Dogs',
#  'Bad Times at the El Royale',
#  'Operation Finale',
#  'Paul, Apostle of Christ',
#  'Lady Bird',
#  'Sorry to Bother You',
#  'Chappaquiddick',
#  'Forever My Girl',
#  'The Favourite',
#  'Hunter Killer',
#  'Mortal Engines',
#  "The Girl in the Spider's Web",
#  'The Possession of Hannah Grace',
#  'RBG',
#  'Eighth Grade',
#  'Call Me by Your Name',
#  'The Darkest Minds',
#  'All the Money in the World',
#  'Three Identical Strangers',
#  'Upgrade',
#  'Padmaavat',
#  'Free Solo',
#  'The Old Man & the Gun',
#  'Hell Fest',
#  'Wonder',
#  'The Miracle Season',
#  'Mary Queen of Scots',
#  'Midnight Sun',
#  'Tully',
#  'Traffik',
#  'Unfriended: Dark Web',
#  'Welcome to Marwen',
#  'Early Man',
#  'The Wife',
#  'The Death of Stalin',
#  'They Shall Not Grow Old',
#  'Sanju',
#  'Unsane',
#  'Beautiful Boy',
#  'Can You Ever Forgive Me?',
#  'Mid90s',
#  'Downsizing',
#  'Dog Days',
#  'Boy Erased',
#  'Hotel Artemis',
#  'A-X-L',
#  'Fahrenheit 11/9',
#  'Unbroken: Path to Redemption',
#  'The Hurricane Heist',
#  'Every Day',
#  'Leave No Trace',
#  'Once Upon a Deadpool',
#  'Death of a Nation',
#  'Pandas',
#  'My Hero Academia: Two Heroes',
#  "God's Not Dead: A Light in Darkness",
#  'Kin',
#  'Colette',
#  'Action Point',
#  'Beirut',
#  'Gringo',
#  'Samson',
#  'Father Figures',
#  'Johnny English Strikes Again',
#  'Gotti',
#  'Blindspotting',
#  'Burn the Stage: The Movie',
#  'Ya veremos',
#  'Life Itself',
#  'Sgt. Stubby: An American Hero',
#  'Thor: Ragnarok',
#  "Gosnell: The Trial of America's Biggest Serial Killer",
#  'Indivisible',
#  'The Oscar Nominated Short Films 2018: Live Action',
#  'Disobedience',
#  'Justice League',
#  'First Reformed',
#  'Juliet, Naked',
#  'Bad Samaritan',
#  '7 Days in Entebbe',
#  'The Disaster Artist',
#  '2001: A Space Odyssey',
#  '2.0',
#  'The Leisure Seeker',
#  'The Sisters Brothers']

# %%
all_titles_2 = []
for title in titles2:
    all_titles_2.append(title.select('a')[0].string)
all_titles_2
# Out:
# ['Avengers: Endgame',
#  'The Lion King',
#  'Toy Story 4',
#  'Frozen II',
#  'Captain Marvel',
#  'Star Wars: Episode IX - The Rise of Skywalker',
#  'Spider-Man: Far from Home',
#  'Aladdin',
#  'Joker',
#  'It Chapter Two',
#  'Jumanji: The Next Level',
#  'Us',
#  'Fast & Furious Presents: Hobbs & Shaw',
#  'John Wick: Chapter 3 - Parabellum',
#  'How to Train Your Dragon: The Hidden World',
#  'The Secret Life of Pets 2',
#  'Pokémon Detective Pikachu',
#  'Once Upon a Time... In Hollywood',
#  'Shazam!',
#  'Aquaman',
#  'Knives Out',
#  'Dumbo',
#  'Maleficent: Mistress of Evil',
#  'Glass',
#  'Godzilla: King of the Monsters',
#  'The Upside',
#  'Ford v Ferrari',
#  'The Lego Movie 2: The Second Part',
#  'Hustlers',
#  'The Addams Family',
#  'Downton Abbey',
#  'Rocketman',
#  'Alita: Battle Angel',
#  'Good Boys',
#  'Spider-Man: Into the Spider-Verse',
#  'Men in Black: International',
#  'Annabelle Comes Home',
#  'Yesterday',
#  'A Madea Family Funeral',
#  'Zombieland: Double Tap',
#  'Angel Has Fallen',
#  'Scary Stories to Tell in the Dark',
#  'Mary Poppins Returns',
#  'X-Men: Dark Phoenix',
#  'Terminator: Dark Fate',
#  'Abominable',
#  'Dora and the Lost City of Gold',
#  'Escape Room',
#  'A Beautiful Day in the Neighborhood',
#  'Midway',
#  'Bumblebee',
#  'The Curse of la Llorona',
#  'Pet Sematary',
#  'What Men Want',
#  'Green Book',
#  'Ad Astra',
#  "Isn't It Romantic",
#  'Gemini Man',
#  'Ma',
#  'Five Feet Apart',
#  'Wonder Park',
#  'Rambo: Last Blood',
#  'Playing with Fire',
#  'Harriet',
#  "A Dog's Way Home",
#  'The Angry Birds Movie 2',
#  'Little',
#  'Queen & Slim',
#  'Breakthrough',
#  'The Mule',
#  'Crawl',
#  'Little Women',
#  'The Intruder',
#  'The Hustle',
#  'Last Christmas',
#  'Overcomer',
#  'Cold Pursuit',
#  'Doctor Sleep',
#  'Dragon Ball Super: Broly',
#  'Long Shot',
#  'Spies in Disguise',
#  "Child's Play",
#  'Ready or Not',
#  'Happy Death Day 2U',
#  'Vice',
#  '21 Bridges',
#  'Midsommar',
#  'Bohemian Rhapsody',
#  'The Art of Racing in the Rain',
#  'Countdown',
#  'Uncut Gems',
#  'Judy',
#  'Ralph Breaks the Internet',
#  'Fighting with My Family',
#  'On the Basis of Sex',
#  "A Dog's Journey",
#  'Booksmart',
#  'Parasite',
#  'Stuber',
#  '47 Meters Down: Uncaged',
#  'Black and Blue',
#  'Hellboy',
#  'Shaft',
#  'Jojo Rabbit',
#  'The Peanut Butter Falcon',
#  'UglyDolls',
#  'Cats',
#  'Unplanned',
#  'The Favourite',
#  'Bombshell',
#  'Richard Jewell',
#  "Charlie's Angels",
#  'The Farewell',
#  'Brightburn',
#  'The Good Liar',
#  'The Kid Who Would Be King',
#  'Missing Link',
#  'Second Act',
#  'Late Night',
#  'Miss Bala',
#  'The Prodigy',
#  'A Star Is Born',
#  'Poms',
#  'If Beale Street Could Talk',
#  'They Shall Not Grow Old',
#  'The Kitchen',
#  'After',
#  'Blinded by the Light',
#  'The Lighthouse',
#  'Dark Waters',
#  'Greta',
#  'The Best of Enemies',
#  'Black Christmas',
#  'Hotel Mumbai',
#  'Holmes & Watson',
#  'Motherless Brooklyn',
#  'No Manches Frida 2',
#  "Where'd You Go, Bernadette",
#  'Apollo 11',
#  'Serenity',
#  'Anna',
#  'Penguins',
#  'Brittany Runs a Marathon',
#  'Mary Queen of Scots',
#  "The Dead Don't Die",
#  'Jexi',
#  'Run the Race',
#  'Free Solo',
#  "The Current War: Director's Cut",
#  'Captive State',
#  'The Wandering Earth',
#  'Arctic Dogs',
#  'Gloria Bell',
#  'Gully Boy',
#  'Stan & Ollie',
#  'The Goldfinch',
#  "Don't Let Go",
#  'The Mustang',
#  'The Sun Is also a Star',
#  'Bring the Soul: The Movie',
#  'Pavarotti',
#  'Tolkien',
#  'The Last Black Man in San Francisco',
#  'War',
#  'Cold War',
#  'Menteur',
#  'Brian Banks',
#  'The Biggest Little Farm',
#  'The Grinch',
#  'Amazing Grace',
#  'Linda Ronstadt: The Sound of My Voice',
#  'Uri: The Surgical Strike',
#  'Replicas',
#  'Pain and Glory',
#  'Ne Zha',
#  'Mission Mangal',
#  'The Oscar Nominated Short Films 2019: Documentary',
#  'BTS World Tour: Love Yourself in Seoul',
#  'The Beach Bum',
#  'Echo in the Canyon',
#  'Creed II',
#  'Jay and Silent Bob Reboot',
#  'Maiden',
#  'Simmba',
#  'Bharat',
#  'Honey Boy',
#  'Friends 25th: The One With The Anniversary',
#  'Saaho',
#  'Fantastic Beasts: The Crimes of Grindelwald',
#  'Kalank',
#  'Tod@s Caen',
#  'Everybody Knows',
#  'Instant Family',
#  'The Art of Self-Defense',
#  'Arctic',
#  'Welcome to Marwen',
#  'My People, My Country',
#  'Promare',
#  'Super 30',
#  'Faustina: Love and Mercy']

# %%
gross = soup.find_all(class_='a-text-right mojo-field-type-money mojo-estimatable')
gross[2].string
# Out:
# '$608,581,744'

# %%
gross_2 = soup2.find_all(class_='a-text-right mojo-field-type-money mojo-estimatable')
gross_2[2].string
# Out:
# '$434,038,008'

# %%
gross_list = []
for i in gross:
    gross_list.append(i.string)
gross_list
# Out:
# ['$700,059,566',
#  '$678,815,482',
#  '$608,581,744',
#  '$417,719,760',
#  '$318,491,426',
#  '$270,620,950',
#  '$404,515,480',
#  '$220,159,104',
#  '$216,648,740',
#  '$213,767,512',
#  '$213,515,506',
#  '$215,288,866',
#  '$335,061,807',
#  '$216,428,042',
#  '$188,024,361',
#  '$201,091,711',
#  '$174,532,921',
#  '$167,510,016',
#  '$159,342,015',
#  '$159,555,901',
#  '$145,443,742',
#  '$140,218,711',
#  '$137,690,172',
#  '$174,340,174',
#  '$120,634,935',
#  '$117,450,119',
#  '$115,253,424',
#  '$115,715,889',
#  '$190,241,310',
#  '$171,958,438',
#  '$620,181,382',
#  '$102,084,362',
#  '$101,028,233',
#  '$100,478,608',
#  '$100,407,760',
#  '$99,215,042',
#  '$83,482,352',
#  '$83,240,103',
#  '$81,903,458',
#  '$77,339,130',
#  '$127,195,589',
#  '$69,488,745',
#  '$69,179,066',
#  '$68,566,296',
#  '$68,549,695',
#  '$68,420,120',
#  '$67,745,330',
#  '$67,363,237',
#  '$103,804,407',
#  '$60,311,495',
#  '$59,874,525',
#  '$58,250,803',
#  '$58,032,443',
#  '$54,730,625',
#  '$54,858,851',
#  '$53,548,586',
#  '$53,059,911',
#  '$51,024,708',
#  '$50,316,123',
#  '$50,072,235',
#  '$48,795,601',
#  '$49,275,340',
#  '$63,859,435',
#  '$46,874,505',
#  '$46,840,590',
#  '$46,700,633',
#  '$45,819,713',
#  '$44,947,622',
#  '$44,936,545',
#  '$44,069,456',
#  '$43,549,096',
#  '$43,242,871',
#  '$42,469,946',
#  '$42,402,632',
#  '$104,897,530',
#  '$41,411,015',
#  '$40,891,591',
#  '$40,826,341',
#  '$56,468,410',
#  '$36,343,858',
#  '$36,276,286',
#  '$36,108,758',
#  '$35,857,181',
#  '$35,418,723',
#  '$34,017,028',
#  '$33,562,069',
#  '$32,732,301',
#  '$85,080,171',
#  '$32,015,231',
#  '$31,713,110',
#  '$31,445,012',
#  '$84,410,380',
#  '$30,824,628',
#  '$30,617,396',
#  '$30,569,484',
#  '$54,513,740',
#  '$210,460,015',
#  '$29,790,236',
#  '$29,819,114',
#  '$29,719,483',
#  '$30,014,539',
#  '$26,020,957',
#  '$25,091,816',
#  '$24,586,708',
#  '$24,011,188',
#  '$39,282,227',
#  '$28,780,744',
#  '$22,835,787',
#  '$21,704,844',
#  '$30,573,626',
#  '$20,877,013',
#  '$20,706,452',
#  '$21,198,205',
#  '$20,545,116',
#  '$47,836,282',
#  '$17,857,020',
#  '$17,839,115',
#  '$17,612,099',
#  '$17,560,475',
#  '$48,958,273',
#  '$17,493,096',
#  '$17,395,520',
#  '$16,376,066',
#  '$34,366,783',
#  '$15,767,460',
#  '$15,951,040',
#  '$14,841,338',
#  '$14,837,422',
#  '$14,017,361',
#  '$13,539,709',
#  '$18,095,701',
#  '$12,695,691',
#  '$25,113,707',
#  '$12,320,845',
#  '$11,977,130',
#  '$11,846,060',
#  '$17,541,090',
#  '$11,277,120',
#  '$11,107,431',
#  '$132,422,809',
#  '$10,230,620',
#  '$16,468,499',
#  '$9,561,064',
#  '$9,369,755',
#  '$9,186,156',
#  '$8,866,745',
#  '$10,763,520',
#  '$8,267,544',
#  '$9,601,092',
#  '$8,047,856',
#  '$17,956,913',
#  '$7,909,317',
#  '$7,732,899',
#  '$7,649,973',
#  '$8,803,865',
#  '$7,362,439',
#  '$24,449,754',
#  '$6,809,080',
#  '$6,788,692',
#  '$6,708,147',
#  '$6,501,381',
#  '$6,352,306',
#  '$6,216,897',
#  '$6,115,825',
#  '$6,102,076',
#  '$6,046,104',
#  '$6,100,309',
#  '$5,885,881',
#  '$7,574,012',
#  '$5,754,556',
#  '$5,728,940',
#  '$5,718,096',
#  '$5,137,622',
#  '$5,059,608',
#  '$5,019,226',
#  '$4,969,853',
#  '$4,719,928',
#  '$17,501,244',
#  '$4,412,170',
#  '$4,343,227',
#  '$4,333,394',
#  '$4,201,819',
#  '$4,165,949',
#  '$4,102,648',
#  '$4,015,935',
#  '$315,058,289',
#  '$3,679,893',
#  '$3,511,417',
#  '$3,508,777',
#  '$3,498,782',
#  '$229,024,295',
#  '$3,448,256',
#  '$3,444,895',
#  '$3,435,047',
#  '$3,326,885',
#  '$21,120,616',
#  '$3,236,321',
#  '$4,152,000',
#  '$3,226,443',
#  '$3,143,056']

# %%
gross_list2 = []
for i in gross_2:
    gross_list2.append(i.string)
gross_list2
# Out:
# ['$858,373,000',
#  '$543,638,043',
#  '$434,038,008',
#  '$477,373,578',
#  '$426,829,839',
#  '$515,202,542',
#  '$390,532,085',
#  '$355,559,216',
#  '$335,451,311',
#  '$211,593,228',
#  '$320,314,960',
#  '$175,084,580',
#  '$173,956,935',
#  '$171,015,687',
#  '$160,799,505',
#  '$158,874,395',
#  '$144,105,346',
#  '$142,502,728',
#  '$140,371,656',
#  '$335,061,807',
#  '$165,363,234',
#  '$114,766,307',
#  '$113,929,605',
#  '$111,048,468',
#  '$110,500,138',
#  '$108,252,517',
#  '$117,624,357',
#  '$105,806,508',
#  '$104,963,598',
#  '$100,044,905',
#  '$96,854,135',
#  '$96,368,160',
#  '$85,838,210',
#  '$83,140,306',
#  '$190,241,310',
#  '$80,001,807',
#  '$74,152,591',
#  '$73,286,650',
#  '$73,257,045',
#  '$73,123,082',
#  '$69,030,436',
#  '$68,947,075',
#  '$171,958,438',
#  '$65,845,974',
#  '$62,253,077',
#  '$60,716,390',
#  '$60,477,943',
#  '$57,005,601',
#  '$61,704,055',
#  '$56,846,802',
#  '$127,195,589',
#  '$54,733,739',
#  '$54,724,696',
#  '$54,611,903',
#  '$85,080,171',
#  '$50,188,370',
#  '$48,791,187',
#  '$48,546,770',
#  '$45,896,028',
#  '$45,729,221',
#  '$45,216,793',
#  '$44,819,352',
#  '$44,451,847',
#  '$43,082,155',
#  '$42,004,346',
#  '$41,667,116',
#  '$40,860,481',
#  '$43,808,310',
#  '$40,713,082',
#  '$103,804,407',
#  '$39,014,193',
#  '$108,101,214',
#  '$35,419,122',
#  '$35,417,038',
#  '$35,150,750',
#  '$34,746,945',
#  '$32,138,862',
#  '$31,581,712',
#  '$30,712,119',
#  '$30,316,271',
#  '$66,757,013',
#  '$29,208,403',
#  '$28,714,231',
#  '$28,148,130',
#  '$47,836,282',
#  '$28,539,757',
#  '$27,426,361',
#  '$216,428,042',
#  '$26,395,642',
#  '$25,621,766',
#  '$50,023,780',
#  '$24,313,888',
#  '$201,091,711',
#  '$22,958,886',
#  '$24,622,687',
#  '$22,782,371',
#  '$22,680,962',
#  '$53,369,749',
#  '$22,370,452',
#  '$22,260,900',
#  '$22,055,313',
#  '$21,903,748',
#  '$21,360,215',
#  '$33,370,906',
#  '$20,457,151',
#  '$20,150,241',
#  '$27,166,770',
#  '$19,005,109',
#  '$34,366,783',
#  '$31,762,808',
#  '$22,345,542',
#  '$17,803,077',
#  '$17,695,781',
#  '$17,300,439',
#  '$17,156,058',
#  '$16,790,790',
#  '$16,649,539',
#  '$39,282,227',
#  '$15,499,454',
#  '$15,006,824',
#  '$14,856,291',
#  '$215,288,866',
#  '$13,631,124',
#  '$14,915,773',
#  '$17,956,913',
#  '$12,180,032',
#  '$12,138,565',
#  '$11,901,145',
#  '$10,867,104',
#  '$11,136,084',
#  '$10,532,219',
#  '$10,205,616',
#  '$10,429,730',
#  '$9,651,611',
#  '$30,573,626',
#  '$9,277,736',
#  '$9,270,920',
#  '$9,198,356',
#  '$9,039,891',
#  '$8,547,045',
#  '$7,743,794',
#  '$7,699,452',
#  '$7,189,808',
#  '$16,468,499',
#  '$6,563,605',
#  '$6,546,159',
#  '$6,424,420',
#  '$17,541,090',
#  '$5,979,540',
#  '$5,958,315',
#  '$5,971,413',
#  '$5,801,249',
#  '$5,611,123',
#  '$5,566,534',
#  '$5,470,235',
#  '$5,332,621',
#  '$5,215,062',
#  '$5,043,620',
#  '$4,950,029',
#  '$4,809,800',
#  '$4,600,249',
#  '$4,535,154',
#  '$4,515,719',
#  '$4,654,000',
#  '$4,580,048',
#  '$4,697,364',
#  '$4,376,819',
#  '$4,366,949',
#  '$270,620,950',
#  '$4,450,456',
#  '$4,252,657',
#  '$4,186,168',
#  '$4,046,429',
#  '$4,567,338',
#  '$3,695,533',
#  '$3,659,413',
#  '$3,531,094',
#  '$3,509,917',
#  '$3,502,600',
#  '$3,355,324',
#  '$115,715,889',
#  '$4,589,490',
#  '$3,168,978',
#  '$5,102,129',
#  '$2,971,549',
#  '$3,012,615',
#  '$2,884,827',
#  '$2,872,057',
#  '$159,555,901',
#  '$2,729,336',
#  '$2,670,925',
#  '$2,660,165',
#  '$67,363,237',
#  '$2,410,914',
#  '$2,410,795',
#  '$10,763,520',
#  '$2,356,683',
#  '$2,313,596',
#  '$2,269,878',
#  '$2,243,180']

# %%
theaters = soup.find_all(class_='a-text-right mojo-field-type-positive_integer')
theaters[0].string
# Out:
# '4,084'

# %%
theaters2 = soup2.find_all(class_='a-text-right mojo-field-type-positive_integer')
theaters2[0].string
# Out:
# '4,662'

# %%
theater_list = []
for i in theaters:
    theater_list.append(i.string)
theater_list
# Out:
# ['4,084',
#  '4,474',
#  '4,410',
#  '4,485',
#  '4,349',
#  '4,141',
#  '3,849',
#  '4,395',
#  '4,206',
#  '4,381',
#  '4,250',
#  '3,904',
#  '4,184',
#  '4,000',
#  '3,808',
#  '4,017',
#  '3,865',
#  '4,267',
#  '3,990',
#  '4,163',
#  '4,118',
#  '4,145',
#  '4,234',
#  '3,342',
#  '3,514',
#  '3,876',
#  '3,725',
#  '3,752',
#  '3,813',
#  '4,090',
#  '4,232',
#  '3,388',
#  '4,115',
#  '3,980',
#  '3,768',
#  '3,602',
#  '2,894',
#  '4,131',
#  '2,851',
#  '3,019',
#  '3,597',
#  '3,038',
#  '3,502',
#  '3,169',
#  '3,592',
#  '3,822',
#  '3,150',
#  '3,426',
#  '3,329',
#  '3,418',
#  '3,708',
#  '3,854',
#  '3,793',
#  '3,382',
#  '3,766',
#  '3,102',
#  '3,656',
#  '4,070',
#  '2,006',
#  '3,055',
#  '3,440',
#  '1,914',
#  '2,341',
#  '3,064',
#  '2,537',
#  '3,723',
#  '3,018',
#  '2,432',
#  '3,640',
#  '2,998',
#  '2,006',
#  '3,662',
#  '2,742',
#  '2,803',
#  '3,468',
#  '3,068',
#  '3,702',
#  '2,434',
#  '1,733',
#  '2,892',
#  '3,042',
#  '3,520',
#  '2,881',
#  '2,980',
#  '2,882',
#  '3,111',
#  '2,112',
#  '2,648',
#  '1,947',
#  '2,468',
#  '3,015',
#  '3,630',
#  '2,827',
#  '2,125',
#  '2,358',
#  '1,726',
#  '3,987',
#  '3,188',
#  '2,934',
#  '2,375',
#  '1,450',
#  '2,009',
#  '2,480',
#  '2,464',
#  '2,504',
#  '2,607',
#  '1,708',
#  '893',
#  '2,859',
#  '2,780',
#  '2,125',
#  '3,256',
#  '1,186',
#  '2,220',
#  '2,534',
#  '3,212',
#  '2,808',
#  '1,818',
#  '1,473',
#  '1,557',
#  '1,050',
#  '1,645',
#  '1,427',
#  '1,554',
#  '2,728',
#  '3,103',
#  '2,929',
#  '2,298',
#  '432',
#  '1,084',
#  '914',
#  '3,127',
#  '2,123',
#  '433',
#  '1,458',
#  '354',
#  '483',
#  '1,042',
#  '2,297',
#  '3,519',
#  '1,707',
#  '1,052',
#  '2,173',
#  '1,356',
#  '1,046',
#  '1,547',
#  '1,911',
#  '2,494',
#  '541',
#  '548',
#  '1,335',
#  '359',
#  '2,023',
#  '776',
#  '555',
#  '1,206',
#  '2,668',
#  '2,442',
#  '672',
#  '2,407',
#  '1,710',
#  '1,719',
#  '1,620',
#  '2,402',
#  '1,669',
#  '361',
#  '1,566',
#  '1,005',
#  '35',
#  '535',
#  '1,693',
#  '2,141',
#  '593',
#  '2,032',
#  '755',
#  '2,404',
#  '1,249',
#  '2,902',
#  '552',
#  '503',
#  '523',
#  '645',
#  '369',
#  '2,609',
#  '1,633',
#  '4,080',
#  '673',
#  '830',
#  '272',
#  '247',
#  '4,051',
#  '334',
#  '467',
#  '2,007',
#  '838',
#  '1,010',
#  '13',
#  '314',
#  '353',
#  '1,141']

# %%
theater_list2 = []
for i in theaters2:
    theater_list2.append(i.string)
theater_list2
# Out:
# ['4,662',
#  '4,802',
#  '4,575',
#  '4,440',
#  '4,310',
#  '4,406',
#  '4,634',
#  '4,476',
#  '4,374',
#  '4,570',
#  '4,227',
#  '3,743',
#  '4,344',
#  '3,850',
#  '4,286',
#  '4,564',
#  '4,248',
#  '3,659',
#  '4,306',
#  '4,184',
#  '3,461',
#  '4,259',
#  '3,820',
#  '3,844',
#  '4,108',
#  '3,568',
#  '3,746',
#  '4,303',
#  '3,525',
#  '4,107',
#  '3,548',
#  '3,610',
#  '3,802',
#  '3,458',
#  '3,813',
#  '4,224',
#  '3,613',
#  '2,755',
#  '2,442',
#  '3,468',
#  '3,336',
#  '3,135',
#  '4,090',
#  '3,721',
#  '4,086',
#  '4,248',
#  '3,735',
#  '2,717',
#  '3,491',
#  '3,242',
#  '3,597',
#  '3,372',
#  '3,585',
#  '2,912',
#  '2,648',
#  '3,460',
#  '3,444',
#  '3,642',
#  '2,816',
#  '2,866',
#  '3,838',
#  '3,618',
#  '3,185',
#  '2,186',
#  '3,090',
#  '3,869',
#  '2,667',
#  '1,715',
#  '2,913',
#  '3,329',
#  '3,170',
#  '3,308',
#  '2,231',
#  '3,077',
#  '3,454',
#  '2,293',
#  '2,630',
#  '3,855',
#  '1,267',
#  '3,230',
#  '3,502',
#  '3,007',
#  '2,998',
#  '3,212',
#  '2,534',
#  '2,665',
#  '2,707',
#  '4,000',
#  '2,765',
#  '2,675',
#  '2,686',
#  '1,627',
#  '4,017',
#  '2,855',
#  '1,957',
#  '3,279',
#  '2,518',
#  '2,001',
#  '3,050',
#  '2,883',
#  '2,062',
#  '3,303',
#  '2,952',
#  '1,173',
#  '1,490',
#  '3,652',
#  '3,380',
#  '1,516',
#  '1,554',
#  '1,721',
#  '2,502',
#  '3,452',
#  '891',
#  '2,607',
#  '2,454',
#  '3,528',
#  '3,437',
#  '2,607',
#  '2,220',
#  '2,203',
#  '2,530',
#  '3,904',
#  '2,750',
#  '1,018',
#  '1,335',
#  '2,745',
#  '2,138',
#  '2,307',
#  '978',
#  '2,112',
#  '2,417',
#  '1,705',
#  '2,625',
#  '930',
#  '2,780',
#  '1,342',
#  '472',
#  '2,404',
#  '588',
#  '2,561',
#  '2,114',
#  '1,815',
#  '1,033',
#  '1,052',
#  '690',
#  '2,332',
#  '1,075',
#  '483',
#  '1,082',
#  '2,549',
#  '129',
#  '2,844',
#  '1,127',
#  '270',
#  '754',
#  '2,542',
#  '922',
#  '527',
#  '2,073',
#  '873',
#  '288',
#  '1,501',
#  '207',
#  '305',
#  '270',
#  '89',
#  '1,240',
#  '285',
#  '4,141',
#  '263',
#  '247',
#  '132',
#  '2,329',
#  '266',
#  '135',
#  '263',
#  '415',
#  '997',
#  '1,100',
#  '147',
#  '3,752',
#  '788',
#  '180',
#  '301',
#  '311',
#  '460',
#  '1,586',
#  '381',
#  '4,163',
#  '320',
#  '371',
#  '283',
#  '3,426',
#  '550',
#  '268',
#  '1,911',
#  '83',
#  '701',
#  '317',
#  '810']

# %%
release_date = soup.find_all(class_ = 'a-text-left mojo-field-type-date a-nowrap')
release_date[0].string
# Out:
# 'Feb 16'

# %%
release_date2 = soup2.find_all(class_ = 'a-text-left mojo-field-type-date a-nowrap')
release_date2[0].string
# Out:
# 'Apr 26'

# %%
release_date_list = []
for i in release_date:
    release_date_list.append(i.string)
release_date_list
# Out:
# ['Feb 16',
#  'Apr 27',
#  'Jun 15',
#  'Jun 22',
#  'May 18',
#  'Nov 9',
#  'Dec 20',
#  'Jul 27',
#  'Jul 6',
#  'May 25',
#  'Oct 5',
#  'Oct 5',
#  'Dec 21',
#  'Nov 2',
#  'Apr 6',
#  'Nov 21',
#  'Aug 15',
#  'Jul 13',
#  'Oct 19',
#  'Nov 16',
#  'Aug 10',
#  'Jun 8',
#  'Mar 29',
#  'Dec 20',
#  'Jul 20',
#  'Sep 7',
#  'Feb 9',
#  'Nov 21',
#  'Dec 14',
#  'Dec 19',
#  'Dec 15',
#  'Jul 20',
#  'Apr 13',
#  'Mar 9',
#  'Feb 9',
#  'Aug 3',
#  'Mar 16',
#  'Sep 28',
#  'Dec 22',
#  'Sep 28',
#  'Dec 21',
#  'Jul 4',
#  'Feb 23',
#  'May 18',
#  'Sep 21',
#  'Jul 13',
#  'Jan 5',
#  'Nov 16',
#  'Dec 14',
#  'Apr 6',
#  'Mar 23',
#  'Mar 16',
#  'Jan 26',
#  'Jun 15',
#  'Nov 2',
#  'Sep 14',
#  'May 11',
#  'Sep 14',
#  'May 4',
#  'Jun 29',
#  'Apr 20',
#  'Aug 10',
#  'Dec 1',
#  'Mar 2',
#  'May 11',
#  'Oct 12',
#  'Jan 19',
#  'Jan 19',
#  'Oct 12',
#  'Jun 8',
#  'Mar 30',
#  'Mar 23',
#  'Jun 29',
#  'Nov 16',
#  'Dec 22',
#  'Apr 13',
#  'Jan 12',
#  'Mar 16',
#  'Nov 22',
#  'Jan 12',
#  'Feb 9',
#  'Aug 17',
#  'Aug 17',
#  'Sep 7',
#  'Mar 2',
#  'Aug 3',
#  'Feb 23',
#  'Nov 16',
#  'Mar 23',
#  'Nov 2',
#  'Jun 1',
#  'Dec 15',
#  'Nov 21',
#  'Apr 20',
#  'Aug 10',
#  'Nov 10',
#  'Nov 22',
#  'Jul 27',
#  'Dec 22',
#  'Oct 5',
#  'Dec 8',
#  'Aug 24',
#  'Feb 2',
#  'Mar 9',
#  'Sep 14',
#  'Dec 21',
#  'Dec 25',
#  'Jun 8',
#  'Nov 9',
#  'Dec 25',
#  'Jan 12',
#  'Aug 24',
#  'Dec 25',
#  'Jun 13',
#  'Dec 25',
#  'May 18',
#  'Oct 12',
#  'Aug 29',
#  'Mar 23',
#  'Nov 3',
#  'Jul 6',
#  'Apr 6',
#  'Jan 19',
#  'Nov 23',
#  'Oct 26',
#  'Dec 14',
#  'Nov 9',
#  'Nov 30',
#  'May 4',
#  'Jul 13',
#  'Nov 24',
#  'Aug 3',
#  'Dec 25',
#  'Jun 29',
#  'Jun 1',
#  'Jan 25',
#  'Sep 28',
#  'Sep 28',
#  'Sep 28',
#  'Nov 17',
#  'Apr 6',
#  'Dec 7',
#  'Mar 23',
#  'May 4',
#  'Apr 20',
#  'Jul 20',
#  'Dec 21',
#  'Feb 16',
#  'Aug 17',
#  'Mar 9',
#  'Dec 17',
#  'Jun 29',
#  'Mar 23',
#  'Oct 12',
#  'Oct 19',
#  'Oct 19',
#  'Dec 22',
#  'Aug 8',
#  'Nov 2',
#  'Jun 8',
#  'Aug 24',
#  'Sep 21',
#  'Sep 14',
#  'Mar 9',
#  'Feb 23',
#  'Jun 29',
#  'Dec 12',
#  'Aug 3',
#  'Apr 6',
#  'Sep 25',
#  'Mar 30',
#  'Aug 31',
#  'Sep 21',
#  'Jun 1',
#  'Apr 11',
#  'Mar 9',
#  'Feb 16',
#  'Dec 22',
#  'Oct 26',
#  'Jun 15',
#  'Jul 20',
#  'Nov 15',
#  'Aug 31',
#  'Sep 21',
#  'Apr 13',
#  'Nov 3',
#  'Oct 12',
#  'Oct 26',
#  'Feb 9',
#  'Apr 27',
#  'Nov 17',
#  'May 18',
#  'Aug 17',
#  'May 4',
#  'Mar 16',
#  'Dec 1',
#  'May 18',
#  'Nov 30',
#  'Dec 15',
#  'Sep 21']

# %%
release_date_list2 = []
for i in release_date2:
    release_date_list2.append(i.string)
release_date_list2
# Out:
# ['Apr 26',
#  'Jul 19',
#  'Jun 21',
#  'Nov 22',
#  'Mar 8',
#  'Dec 20',
#  'Jul 2',
#  'May 24',
#  'Oct 4',
#  'Sep 6',
#  'Dec 13',
#  'Mar 22',
#  'Aug 2',
#  'May 17',
#  'Feb 22',
#  'Jun 7',
#  'May 10',
#  'Jul 26',
#  'Apr 5',
#  'Dec 21',
#  'Nov 27',
#  'Mar 29',
#  'Oct 18',
#  'Jan 18',
#  'May 31',
#  'Jan 11',
#  'Nov 15',
#  'Feb 8',
#  'Sep 13',
#  'Oct 11',
#  'Sep 20',
#  'May 31',
#  'Feb 14',
#  'Aug 16',
#  'Dec 14',
#  'Jun 14',
#  'Jun 26',
#  'Jun 28',
#  'Mar 1',
#  'Oct 18',
#  'Aug 23',
#  'Aug 9',
#  'Dec 19',
#  'Jun 7',
#  'Nov 1',
#  'Sep 27',
#  'Aug 9',
#  'Jan 4',
#  'Nov 22',
#  'Nov 8',
#  'Dec 21',
#  'Apr 19',
#  'Apr 5',
#  'Feb 8',
#  'Nov 16',
#  'Sep 20',
#  'Feb 13',
#  'Oct 11',
#  'May 31',
#  'Mar 15',
#  'Mar 15',
#  'Sep 20',
#  'Nov 8',
#  'Nov 1',
#  'Jan 11',
#  'Aug 13',
#  'Apr 12',
#  'Nov 27',
#  'Apr 17',
#  'Dec 14',
#  'Jul 12',
#  'Dec 25',
#  'May 3',
#  'May 10',
#  'Nov 8',
#  'Aug 23',
#  'Feb 8',
#  'Nov 8',
#  'Jan 16',
#  'May 3',
#  'Dec 25',
#  'Jun 21',
#  'Aug 21',
#  'Feb 13',
#  'Dec 25',
#  'Nov 22',
#  'Jul 3',
#  'Nov 2',
#  'Aug 9',
#  'Oct 25',
#  'Dec 13',
#  'Sep 27',
#  'Nov 21',
#  'Feb 14',
#  'Dec 25',
#  'May 17',
#  'May 24',
#  'Oct 11',
#  'Jul 12',
#  'Aug 16',
#  'Oct 25',
#  'Apr 12',
#  'Jun 14',
#  'Oct 18',
#  'Aug 9',
#  'May 3',
#  'Dec 20',
#  'Mar 29',
#  'Nov 23',
#  'Dec 13',
#  'Dec 13',
#  'Nov 15',
#  'Jul 12',
#  'May 24',
#  'Nov 15',
#  'Jan 25',
#  'Apr 12',
#  'Dec 21',
#  'Jun 7',
#  'Feb 1',
#  'Feb 8',
#  'Oct 5',
#  'May 10',
#  'Dec 14',
#  'Dec 17',
#  'Aug 9',
#  'Apr 12',
#  'Aug 16',
#  'Oct 18',
#  'Nov 22',
#  'Mar 1',
#  'Apr 5',
#  'Dec 13',
#  'Mar 22',
#  'Dec 25',
#  'Nov 1',
#  'Mar 15',
#  'Aug 16',
#  'Mar 1',
#  'Jan 25',
#  'Jun 21',
#  'Apr 17',
#  'Aug 23',
#  'Dec 7',
#  'Jun 14',
#  'Oct 11',
#  'Feb 22',
#  'Sep 28',
#  'Oct 25',
#  'Mar 15',
#  'Feb 5',
#  'Nov 1',
#  'Mar 8',
#  'Feb 14',
#  'Dec 28',
#  'Sep 13',
#  'Aug 30',
#  'Mar 15',
#  'May 17',
#  'Aug 7',
#  'Jun 7',
#  'May 10',
#  'Jun 7',
#  'Oct 2',
#  'Dec 21',
#  'Jul 12',
#  'Aug 9',
#  'May 10',
#  'Nov 9',
#  'Dec 7',
#  'Sep 6',
#  'Jan 11',
#  'Jan 11',
#  'Oct 4',
#  'Aug 29',
#  'Aug 15',
#  'Feb 8',
#  'Jan 26',
#  'Mar 29',
#  'May 24',
#  'Nov 21',
#  'Oct 15',
#  'Jun 28',
#  'Dec 28',
#  'Jun 5',
#  'Nov 8',
#  'Sep 23',
#  'Aug 29',
#  'Nov 16',
#  'Apr 17',
#  'Aug 30',
#  'Feb 8',
#  'Nov 16',
#  'Jul 12',
#  'Feb 1',
#  'Dec 21',
#  'Oct 1',
#  'Sep 17',
#  'Jul 12',
#  'Oct 28']

# %%
distributor = soup.find_all(class_ = 'a-text-left mojo-field-type-studio')
distributor[0].get_text()
# Out:
# 'Walt Disney Studios Motion Pictures\n\n'

# %%
distributor2 = soup2.find_all(class_ = 'a-text-left mojo-field-type-studio')
distributor2[0].get_text()
# Out:
# 'Walt Disney Studios Motion Pictures\n\n'

# %%
distributor_list = []
for i in distributor:
    distributor_list.append(i.get_text())
distributor_list
# Out:
# ['Walt Disney Studios Motion Pictures\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Twentieth Century Fox\n\n',
#  'Universal Pictures\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Paramount Pictures\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Warner Bros.\n\n',
#  'Warner Bros.\n\n',
#  'Twentieth Century Fox\n\n',
#  'Paramount Pictures\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Warner Bros.\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Universal Pictures\n\n',
#  'Warner Bros.\n\n',
#  'Warner Bros.\n\n',
#  'Warner Bros.\n\n',
#  'Warner Bros.\n\n',
#  'Twentieth Century Fox\n\n',
#  'Universal Pictures\n\n',
#  'Warner Bros.\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Metro-Goldwyn-Mayer (MGM)\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Warner Bros.\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Roadside Attractions\n\n',
#  'Warner Bros.\n\n',
#  'Twentieth Century Fox\n\n',
#  'Universal Pictures\n\n',
#  'Paramount Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Warner Bros.\n\n',
#  'Paramount Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Paramount Pictures\n\n',
#  'Warner Bros.\n\n',
#  'Universal Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Warner Bros.\n\n',
#  'Twentieth Century Fox\n\n',
#  'Warner Bros.\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Lionsgate\n\n',
#  'Warner Bros.\n\n',
#  'Twentieth Century Fox\n\n',
#  'Pantelion Films\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'STX Entertainment\n\n',
#  'Focus Features\n\n',
#  'Fox Searchlight Pictures\n\n',
#  'Twentieth Century Fox\n\n',
#  'Universal Pictures\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Warner Bros.\n\n',
#  'STX Entertainment\n\n',
#  'Universal Pictures\n\n',
#  'A24\n\n',
#  'Lionsgate\n\n',
#  'Paramount Pictures\n\n',
#  'Lionsgate\n\n',
#  'Twentieth Century Fox\n\n',
#  'Universal Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Warner Bros.\n\n',
#  'Twentieth Century Fox\n\n',
#  'Focus Features\n\n',
#  'Lionsgate\n\n',
#  'Warner Bros.\n\n',
#  'STX Entertainment\n\n',
#  'Studio 8\n\n',
#  'STX Entertainment\n\n',
#  'Metro-Goldwyn-Mayer (MGM)\n\n',
#  'Lionsgate\n\n',
#  'Paramount Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Fox Searchlight Pictures\n\n',
#  'Paramount Pictures\n\n',
#  'STX Entertainment\n\n',
#  'Twentieth Century Fox\n\n',
#  'Lionsgate\n\n',
#  'Twentieth Century Fox\n\n',
#  'Screen Gems\n\n',
#  'Fox Searchlight Pictures\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Warner Bros.\n\n',
#  'Entertainment Studios Motion Pictures\n\n',
#  'Twentieth Century Fox\n\n',
#  'Neon\n\n',
#  'Screen Gems\n\n',
#  'Lionsgate\n\n',
#  'Aviron Pictures\n\n',
#  'Studio 8\n\n',
#  'STX Entertainment\n\n',
#  'STX Entertainment\n\n',
#  'Focus Features\n\n',
#  'Paramount Pictures\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Screen Gems\n\n',
#  'STX Entertainment\n\n',
#  'Focus Features\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Annapurna Pictures\n\n',
#  '-',
#  'Twentieth Century Fox\n\n',
#  'Metro-Goldwyn-Mayer (MGM)\n\n',
#  'Affirm Films\n\n',
#  'A24\n\n',
#  'Annapurna Pictures\n\n',
#  'Entertainment Studios Motion Pictures\n\n',
#  'Roadside Attractions\n\n',
#  'Fox Searchlight Pictures\n\n',
#  'Lionsgate\n\n',
#  'Universal Pictures\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Screen Gems\n\n',
#  'Magnolia Pictures\n\n',
#  'A24\n\n',
#  'Sony Pictures Classics\n\n',
#  'Twentieth Century Fox\n\n',
#  'TriStar Pictures\n\n',
#  'Neon\n\n',
#  'BH Tilt\n\n',
#  'Viva Pictures\n\n',
#  'National Geographic Entertainment\n\n',
#  'Fox Searchlight Pictures\n\n',
#  'Lionsgate\n\n',
#  'Lionsgate\n\n',
#  '-',
#  'Focus Features\n\n',
#  '-',
#  'Focus Features\n\n',
#  'Lionsgate\n\n',
#  'BH Tilt\n\n',
#  'Universal Pictures\n\n',
#  'Lionsgate\n\n',
#  'Sony Pictures Classics\n\n',
#  'IFC Films\n\n',
#  'Warner Bros.\n\n',
#  'FIP\n\n',
#  'Bleecker Street Media\n\n',
#  'Amazon Studios\n\n',
#  'Fox Searchlight Pictures\n\n',
#  'A24\n\n',
#  'Paramount Pictures\n\n',
#  'LD Entertainment\n\n',
#  'Focus Features\n\n',
#  '-',
#  '-',
#  '-',
#  'Pure Flix Entertainment\n\n',
#  'Entertainment Studios Motion Pictures\n\n',
#  'Orion Pictures\n\n',
#  'Bleecker Street Media\n\n',
#  'Twentieth Century Fox\n\n',
#  '-',
#  'Warner Bros.\n\n',
#  'FUNimation Entertainment\n\n',
#  'Pure Flix Entertainment\n\n',
#  'Lionsgate\n\n',
#  'Bleecker Street Media\n\n',
#  'Paramount Pictures\n\n',
#  'Bleecker Street Media\n\n',
#  'STX Entertainment\n\n',
#  'Pure Flix Entertainment\n\n',
#  'Warner Bros.\n\n',
#  'Universal Pictures\n\n',
#  'Vertical Entertainment\n\n',
#  'Lionsgate\n\n',
#  'Trafalgar Releasing\n\n',
#  'Pantelion Films\n\n',
#  'Amazon Studios\n\n',
#  '-',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'GVN Releasing\n\n',
#  'Pure Flix Entertainment\n\n',
#  'Shorts International\n\n',
#  'Bleecker Street Media\n\n',
#  'Warner Bros.\n\n',
#  'A24\n\n',
#  'Roadside Attractions\n\n',
#  'Electric Entertainment\n\n',
#  'Focus Features\n\n',
#  'A24\n\n',
#  'Warner Bros.\n\n',
#  '-',
#  'Sony Pictures Classics\n\n',
#  'Annapurna Pictures\n\n']

# %%
distributor_list2 = []
for i in distributor2:
    distributor_list2.append(i.get_text())
distributor_list2
# Out:
# ['Walt Disney Studios Motion Pictures\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Warner Bros.\n\n',
#  'Warner Bros.\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Universal Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Lionsgate\n\n',
#  'Universal Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Warner Bros.\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Warner Bros.\n\n',
#  'Warner Bros.\n\n',
#  'Lionsgate\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Warner Bros.\n\n',
#  'STX Entertainment\n\n',
#  'Twentieth Century Fox\n\n',
#  'Warner Bros.\n\n',
#  'STX Entertainment\n\n',
#  'United Artists Releasing\n\n',
#  'Focus Features\n\n',
#  'Paramount Pictures\n\n',
#  'Twentieth Century Fox\n\n',
#  'Universal Pictures\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Warner Bros.\n\n',
#  'Universal Pictures\n\n',
#  'Lionsgate\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Lionsgate\n\n',
#  'Lionsgate\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Twentieth Century Fox\n\n',
#  'Paramount Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Paramount Pictures\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Lionsgate\n\n',
#  'Paramount Pictures\n\n',
#  'Warner Bros.\n\n',
#  'Paramount Pictures\n\n',
#  'Paramount Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Twentieth Century Fox\n\n',
#  'Warner Bros.\n\n',
#  'Paramount Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Lionsgate\n\n',
#  'Paramount Pictures\n\n',
#  'Lionsgate\n\n',
#  'Paramount Pictures\n\n',
#  'Focus Features\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Universal Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Twentieth Century Fox\n\n',
#  'Warner Bros.\n\n',
#  'Paramount Pictures\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Screen Gems\n\n',
#  'United Artists Releasing\n\n',
#  'Universal Pictures\n\n',
#  'Affirm Films\n\n',
#  'Lionsgate\n\n',
#  'Warner Bros.\n\n',
#  'FUNimation Entertainment\n\n',
#  'Lionsgate\n\n',
#  'Twentieth Century Fox\n\n',
#  'United Artists Releasing\n\n',
#  'Fox Searchlight Pictures\n\n',
#  'Universal Pictures\n\n',
#  'Annapurna Pictures\n\n',
#  'STX Entertainment\n\n',
#  'A24\n\n',
#  'Twentieth Century Fox\n\n',
#  'Twentieth Century Fox\n\n',
#  'STX Entertainment\n\n',
#  'A24\n\n',
#  'Roadside Attractions\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Metro-Goldwyn-Mayer (MGM)\n\n',
#  'Focus Features\n\n',
#  'Universal Pictures\n\n',
#  'United Artists Releasing\n\n',
#  'Neon\n\n',
#  'Twentieth Century Fox\n\n',
#  'Entertainment Studios Motion Pictures\n\n',
#  'Screen Gems\n\n',
#  'Lionsgate\n\n',
#  'Warner Bros.\n\n',
#  'Fox Searchlight Pictures\n\n',
#  'Roadside Attractions\n\n',
#  'STX Entertainment\n\n',
#  'Universal Pictures\n\n',
#  'Pure Flix Entertainment\n\n',
#  'Fox Searchlight Pictures\n\n',
#  'Lionsgate\n\n',
#  'Warner Bros.\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'A24\n\n',
#  'Screen Gems\n\n',
#  'Warner Bros.\n\n',
#  'Twentieth Century Fox\n\n',
#  'United Artists Releasing\n\n',
#  'STX Entertainment\n\n',
#  'Amazon Studios\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Orion Pictures\n\n',
#  'Warner Bros.\n\n',
#  'STX Entertainment\n\n',
#  'Annapurna Pictures\n\n',
#  'Warner Bros.\n\n',
#  'Warner Bros.\n\n',
#  'Aviron Pictures\n\n',
#  'Warner Bros.\n\n',
#  'A24\n\n',
#  'Focus Features\n\n',
#  'Focus Features\n\n',
#  'STX Entertainment\n\n',
#  'Universal Pictures\n\n',
#  'Bleecker Street Media\n\n',
#  'Sony Pictures Entertainment (SPE)\n\n',
#  'Warner Bros.\n\n',
#  'Pantelion Films\n\n',
#  'United Artists Releasing\n\n',
#  'Neon\n\n',
#  'Aviron Pictures\n\n',
#  'Lionsgate\n\n',
#  'Walt Disney Studios Motion Pictures\n\n',
#  'Amazon Studios\n\n',
#  'Focus Features\n\n',
#  'Focus Features\n\n',
#  'Lionsgate\n\n',
#  'Roadside Attractions\n\n',
#  'National Geographic Entertainment\n\n',
#  '101 Studios\n\n',
#  'Focus Features\n\n',
#  '-',
#  'Entertainment Studios Motion Pictures\n\n',
#  'A24\n\n',
#  'Viva Pictures\n\n',
#  'Sony Pictures Classics\n\n',
#  'Warner Bros.\n\n',
#  '-',
#  'Focus Features\n\n',
#  'Warner Bros.\n\n',
#  'Trafalgar Releasing\n\n',
#  'CBS Films\n\n',
#  'Fox Searchlight Pictures\n\n',
#  'A24\n\n',
#  'Yash Raj Films\n\n',
#  'Amazon Studios\n\n',
#  'Entertainment One\n\n',
#  'Bleecker Street Media\n\n',
#  'Neon\n\n',
#  'Universal Pictures\n\n',
#  'Neon\n\n',
#  'Greenwich Entertainment\n\n',
#  '-',
#  'Entertainment Studios Motion Pictures\n\n',
#  'Sony Pictures Classics\n\n',
#  'Well Go USA Entertainment\n\n',
#  'FIP\n\n',
#  'Shorts International\n\n',
#  'Fathom Events\n\n',
#  'Neon\n\n',
#  'Greenwich Entertainment\n\n',
#  'Metro-Goldwyn-Mayer (MGM)\n\n',
#  'Saban Films\n\n',
#  'Sony Pictures Classics\n\n',
#  'Reliance Big Pictures\n\n',
#  'Viva Pictures\n\n',
#  'Amazon Studios\n\n',
#  'Fathom Events\n\n',
#  'Yash Raj Films\n\n',
#  'Warner Bros.\n\n',
#  'FIP\n\n',
#  'Pantelion Films\n\n',
#  'Focus Features\n\n',
#  'Paramount Pictures\n\n',
#  'Bleecker Street Media\n\n',
#  'Bleecker Street Media\n\n',
#  'Universal Pictures\n\n',
#  '-',
#  'GKIDS\n\n',
#  'Reliance Big Pictures\n\n',
#  'Fathom Events\n\n']

# %%
import numpy as np
movies_2018 = pd.DataFrame(list(zip(all_titles, gross_list, theater_list, release_date_list, distributor_list)),
                           columns =['Movie_Title','Gross_Revenue', 'Amount_of_Theaters', 'Realease_Date', 'Distributor'],)
movies_2019 = pd.DataFrame(list(zip(all_titles_2, gross_list2, theater_list2, release_date_list2, distributor_list2)),
                           columns =['Movie_Title','Gross_Revenue', 'Amount_of_Theaters', 'Realease_Date', 'Distributor'],)

# %%
movies_2019
# Out:
#                   Movie_Title Gross_Revenue Amount_of_Theaters Realease_Date  \
# 0           Avengers: Endgame  $858,373,000              4,662        Apr 26
# 1               The Lion King  $543,638,043              4,802        Jul 19
# 2                 Toy Story 4  $434,038,008              4,575        Jun 21
# 3                   Frozen II  $477,373,578              4,440        Nov 22
# 4              Captain Marvel  $426,829,839              4,310         Mar 8
# ..                        ...           ...                ...           ...
# 195         Welcome to Marwen   $10,763,520              1,911        Dec 21
# 196     My People, My Country    $2,356,683                 83         Oct 1
# 197                   Promare    $2,313,596                701        Sep 17
# 198                  Super 30    $2,269,878                317        Jul 12
# 199  Faustina: Love and Mercy    $2,243,180                810        Oct 28
#
#                                  Distributor
# 0    Walt Disney Studios Motion Pictures\n\n
# 1    Walt Disney Studios Motion Pictures\n\n
# 2    Walt Disney Studios Motion Pictures\n\n
# 3    Walt Disney Studios Motion Pictures\n\n
# 4    Walt Disney Studios Motion Pictures\n\n
# ..                                       ...
# 195                   Universal Pictures\n\n
# 196                                        -
# 197                                GKIDS\n\n
# 198                Reliance Big Pictures\n\n
# 199                        Fathom Events\n\n
#
# [200 rows x 5 columns]

# %%
movies_2018.set_index('Movie_Title', inplace = True)

# %%
movies_2019.set_index('Movie_Title', inplace = True)

# %%
movies_2018.isna().sum()
# Out:
# Gross_Revenue         0
# Amount_of_Theaters    0
# Realease_Date         0
# Distributor           0
# dtype: int64

# %%
(pd.Index(movies_2018)).duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
movies_2018.duplicated().sum()
# Out:
# 0

# %%
##No nulls. No duplicates. Moving on to changing datatypes for gross revenue, amount of theaters, and release date.

# %%
movies_2018['Gross_Revenue'] = movies_2018['Gross_Revenue'].str.replace(r'$', '')

# %%
movies_2018['Gross_Revenue'] = movies_2018['Gross_Revenue'].str.replace(r',', '')

# %%
movies_2018['Gross_Revenue'] = pd.to_numeric(movies_2018['Gross_Revenue'])

# %%
movies_2019['Gross_Revenue'] = movies_2019['Gross_Revenue'].str.replace(r'$', '')

movies_2019['Gross_Revenue'] = movies_2019['Gross_Revenue'].str.replace(r',', '')

movies_2019['Gross_Revenue'] = pd.to_numeric(movies_2019['Gross_Revenue'])

# %%
movies_2018.dtypes
# Out:
# Gross_Revenue          int64
# Amount_of_Theaters    object
# Realease_Date         object
# Distributor           object
# dtype: object

# %%
movies_2019.dtypes
# Out:
# Gross_Revenue          int64
# Amount_of_Theaters    object
# Realease_Date         object
# Distributor           object
# dtype: object

# %%
movies_2018['Amount_of_Theaters'] = movies_2018['Amount_of_Theaters'].str.replace(r',', '')

# %%
movies_2018['Amount_of_Theaters'] = pd.to_numeric(movies_2018['Amount_of_Theaters'])

# %%
movies_2018.dtypes
# Out:
# Gross_Revenue          int64
# Amount_of_Theaters     int64
# Realease_Date         object
# Distributor           object
# dtype: object

# %%
movies_2019['Amount_of_Theaters'] = movies_2019['Amount_of_Theaters'].str.replace(r',', '')

movies_2019['Amount_of_Theaters'] = pd.to_numeric(movies_2019['Amount_of_Theaters'])

movies_2019.dtypes
# Out:
# Gross_Revenue          int64
# Amount_of_Theaters     int64
# Realease_Date         object
# Distributor           object
# dtype: object

# %%
movies_2018['Realease_Date'] = movies_2018.Realease_Date.astype(str)

# %%
movies_2018.dtypes
# Out:
# Gross_Revenue          int64
# Amount_of_Theaters     int64
# Realease_Date         object
# Distributor           object
# dtype: object

# %%
movies_2019['Realease_Date'] = movies_2019.Realease_Date.astype(str)

movies_2019.dtypes
# Out:
# Gross_Revenue          int64
# Amount_of_Theaters     int64
# Realease_Date         object
# Distributor           object
# dtype: object

# %%
pd.to_datetime(movies_2018['Realease_Date'], infer_datetime_format = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2053         try:
# -> 2054             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2055             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-51-a8c33aec210f> in <module>
# ----> 1 pd.to_datetime(movies_2018['Realease_Date'], infer_datetime_format = True)
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     801             result = arg.map(cache_array)
#     802         else:
# --> 803             values = convert_listlike(arg._values, format)
#     804             result = arg._constructor(values, index=arg.index, name=arg.name)
#     805     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     457         assert format is None or infer_datetime_format
#     458         utc = tz == "utc"
# --> 459         result, tz_parsed = objects_to_datetime64ns(
#     460             arg,
#     461             dayfirst=dayfirst,
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2057             return values.view("i8"), tz_parsed
#    2058         except (ValueError, TypeError):
# -> 2059             raise e
#    2060
#    2061     if tz_parsed is not None:
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2042
#    2043     try:
# -> 2044         result, tz_parsed = tslib.array_to_datetime(
#    2045             data,
#    2046             errors=errors,
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_datetime_to_tsobject()
#
# pandas/_libs/tslibs/np_datetime.pyx in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 1-02-16 00:00:00

# %%
movies_2018['Realease_Date'] = movies_2018['Realease_Date'].map(lambda x: str(x)[0:3])

# %%
movies_2018['Realease_Date'].value_counts()
# Out:
# Dec    29
# Nov    26
# Mar    20
# Aug    19
# Sep    17
# Jun    17
# Oct    14
# Apr    14
# May    12
# Jul    12
# Feb    11
# Jan     9
# Name: Realease_Date, dtype: int64

# %%
movies_2019['Realease_Date'] = movies_2019['Realease_Date'].map(lambda x: str(x)[0:3])

top_grossing_2019 = movies_2019['Realease_Date'].value_counts()

# %%
##movies_2018['converted'] = pd.to_datetime(pd.Series(movies_2018["Realease_Date"]))

# %%
movies_2018
# Out:
#                                 Gross_Revenue  Amount_of_Theaters  \
# Movie_Title
# Black Panther                       700059566                4084
# Avengers: Infinity War              678815482                4474
# Incredibles 2                       608581744                4410
# Jurassic World: Fallen Kingdom      417719760                4485
# Deadpool 2                          318491426                4349
# ...                                       ...                 ...
# The Disaster Artist                  21120616                1010
# 2001: A Space Odyssey                 3236321                  13
# 2.0                                   4152000                 314
# The Leisure Seeker                    3226443                 353
# The Sisters Brothers                  3143056                1141
#
#                                Realease_Date  \
# Movie_Title
# Black Panther                            Feb
# Avengers: Infinity War                   Apr
# Incredibles 2                            Jun
# Jurassic World: Fallen Kingdom           Jun
# Deadpool 2                               May
# ...                                      ...
# The Disaster Artist                      Dec
# 2001: A Space Odyssey                    May
# 2.0                                      Nov
# The Leisure Seeker                       Dec
# The Sisters Brothers                     Sep
#
#                                                             Distributor
# Movie_Title
# Black Panther                   Walt Disney Studios Motion Pictures\n\n
# Avengers: Infinity War          Walt Disney Studios Motion Pictures\n\n
# Incredibles 2                   Walt Disney Studios Motion Pictures\n\n
# Jurassic World: Fallen Kingdom                   Universal Pictures\n\n
# Deadpool 2                                    Twentieth Century Fox\n\n
# ...                                                                 ...
# The Disaster Artist                                             A24\n\n
# 2001: A Space Odyssey                                  Warner Bros.\n\n
# 2.0                                                                   -
# The Leisure Seeker                           Sony Pictures Classics\n\n
# The Sisters Brothers                             Annapurna Pictures\n\n
#
# [200 rows x 4 columns]

# %%
movies_2018['Distributor'] = movies_2018['Distributor'].str.rstrip('\n\n')

# %%
movies_2018
# Out:
#                                 Gross_Revenue  Amount_of_Theaters  \
# Movie_Title
# Black Panther                       700059566                4084
# Avengers: Infinity War              678815482                4474
# Incredibles 2                       608581744                4410
# Jurassic World: Fallen Kingdom      417719760                4485
# Deadpool 2                          318491426                4349
# ...                                       ...                 ...
# The Disaster Artist                  21120616                1010
# 2001: A Space Odyssey                 3236321                  13
# 2.0                                   4152000                 314
# The Leisure Seeker                    3226443                 353
# The Sisters Brothers                  3143056                1141
#
#                                Realease_Date  \
# Movie_Title
# Black Panther                            Feb
# Avengers: Infinity War                   Apr
# Incredibles 2                            Jun
# Jurassic World: Fallen Kingdom           Jun
# Deadpool 2                               May
# ...                                      ...
# The Disaster Artist                      Dec
# 2001: A Space Odyssey                    May
# 2.0                                      Nov
# The Leisure Seeker                       Dec
# The Sisters Brothers                     Sep
#
#                                                         Distributor
# Movie_Title
# Black Panther                   Walt Disney Studios Motion Pictures
# Avengers: Infinity War          Walt Disney Studios Motion Pictures
# Incredibles 2                   Walt Disney Studios Motion Pictures
# Jurassic World: Fallen Kingdom                   Universal Pictures
# Deadpool 2                                    Twentieth Century Fox
# ...                                                             ...
# The Disaster Artist                                             A24
# 2001: A Space Odyssey                                  Warner Bros.
# 2.0                                                               -
# The Leisure Seeker                           Sony Pictures Classics
# The Sisters Brothers                             Annapurna Pictures
#
# [200 rows x 4 columns]

# %%
movies_2019['Distributor'] = movies_2019['Distributor'].str.rstrip('\n\n')

movies_2019
# Out:
#                           Gross_Revenue  Amount_of_Theaters Realease_Date  \
# Movie_Title
# Avengers: Endgame             858373000                4662           Apr
# The Lion King                 543638043                4802           Jul
# Toy Story 4                   434038008                4575           Jun
# Frozen II                     477373578                4440           Nov
# Captain Marvel                426829839                4310           Mar
# ...                                 ...                 ...           ...
# Welcome to Marwen              10763520                1911           Dec
# My People, My Country           2356683                  83           Oct
# Promare                         2313596                 701           Sep
# Super 30                        2269878                 317           Jul
# Faustina: Love and Mercy        2243180                 810           Oct
#
#                                                   Distributor
# Movie_Title
# Avengers: Endgame         Walt Disney Studios Motion Pictures
# The Lion King             Walt Disney Studios Motion Pictures
# Toy Story 4               Walt Disney Studios Motion Pictures
# Frozen II                 Walt Disney Studios Motion Pictures
# Captain Marvel            Walt Disney Studios Motion Pictures
# ...                                                       ...
# Welcome to Marwen                          Universal Pictures
# My People, My Country                                       -
# Promare                                                 GKIDS
# Super 30                                Reliance Big Pictures
# Faustina: Love and Mercy                        Fathom Events
#
# [200 rows x 4 columns]

# %%
movies_2018.corr()
# Out:
#                     Gross_Revenue  Amount_of_Theaters
# Gross_Revenue             1.00000             0.60327
# Amount_of_Theaters        0.60327             1.00000

# %%
movies_2019.corr()
# Out:
#                     Gross_Revenue  Amount_of_Theaters
# Gross_Revenue            1.000000            0.604979
# Amount_of_Theaters       0.604979            1.000000

# %%
top_grossing_2018 = movies_2018['Realease_Date'].value_counts()
top_grossing_2019 = movies_2019['Realease_Date'].value_counts()
top_grossing_2019
# Out:
# Dec    26
# Nov    26
# Aug    22
# Oct    18
# May    18
# Feb    16
# Mar    15
# Jun    15
# Apr    12
# Sep    12
# Jan    10
# Jul    10
# Name: Realease_Date, dtype: int64

# %%
from matplotlib import pyplot as plt


fig, ax =plt.subplots()
ax.hist(movies_2018['Realease_Date'],bins =12)
# Out:
# (array([11., 14., 17., 12., 26., 29., 12., 14., 19., 20., 17.,  9.]),
#  array([ 0.        ,  0.91666667,  1.83333333,  2.75      ,  3.66666667,
#          4.58333333,  5.5       ,  6.41666667,  7.33333333,  8.25      ,
#          9.16666667, 10.08333333, 11.        ]),
#  <BarContainer object of 12 artists>)

# %%
movies_2018['Year']= 2018
movies_2019['Year']= 2019

# %%
df = pd.concat([movies_2018,movies_2019])
df
# Out:
#                                 Gross_Revenue  Amount_of_Theaters  \
# Movie_Title
# Black Panther                       700059566                4084
# Avengers: Infinity War              678815482                4474
# Incredibles 2                       608581744                4410
# Jurassic World: Fallen Kingdom      417719760                4485
# Deadpool 2                          318491426                4349
# ...                                       ...                 ...
# Welcome to Marwen                    10763520                1911
# My People, My Country                 2356683                  83
# Promare                               2313596                 701
# Super 30                              2269878                 317
# Faustina: Love and Mercy              2243180                 810
#
#                                Realease_Date  \
# Movie_Title
# Black Panther                            Feb
# Avengers: Infinity War                   Apr
# Incredibles 2                            Jun
# Jurassic World: Fallen Kingdom           Jun
# Deadpool 2                               May
# ...                                      ...
# Welcome to Marwen                        Dec
# My People, My Country                    Oct
# Promare                                  Sep
# Super 30                                 Jul
# Faustina: Love and Mercy                 Oct
#
#                                                         Distributor  Year
# Movie_Title
# Black Panther                   Walt Disney Studios Motion Pictures  2018
# Avengers: Infinity War          Walt Disney Studios Motion Pictures  2018
# Incredibles 2                   Walt Disney Studios Motion Pictures  2018
# Jurassic World: Fallen Kingdom                   Universal Pictures  2018
# Deadpool 2                                    Twentieth Century Fox  2018
# ...                                                             ...   ...
# Welcome to Marwen                                Universal Pictures  2019
# My People, My Country                                             -  2019
# Promare                                                       GKIDS  2019
# Super 30                                      Reliance Big Pictures  2019
# Faustina: Love and Mercy                              Fathom Events  2019
#
# [400 rows x 5 columns]

# %%
fig, ax =plt.subplots()
ax.hist(df['Realease_Date'],bins =12)
# Out:
# (array([27., 26., 32., 30., 52., 55., 22., 32., 41., 35., 29., 19.]),
#  array([ 0.        ,  0.91666667,  1.83333333,  2.75      ,  3.66666667,
#          4.58333333,  5.5       ,  6.41666667,  7.33333333,  8.25      ,
#          9.16666667, 10.08333333, 11.        ]),
#  <BarContainer object of 12 artists>)

# %%
df.groupby(by = 'Realease_Date').mean().round()
# Out:
#                Gross_Revenue  Amount_of_Theaters    Year
# Realease_Date
# Apr               94885644.0              2528.0  2018.0
# Aug               34665603.0              2225.0  2019.0
# Dec               93652990.0              2547.0  2018.0
# Feb               62856269.0              2334.0  2019.0
# Jan               38367531.0              2470.0  2019.0
# Jul              101433046.0              2631.0  2018.0
# Jun               77152630.0              2322.0  2018.0
# Mar               49326607.0              2382.0  2018.0
# May               64691841.0              2597.0  2019.0
# Nov               92764206.0              2899.0  2018.0
# Oct               57535473.0              2184.0  2019.0
# Sep               41620301.0              2395.0  2018.0

# %%
#We have the most Top Grossing Movies in December and November. The problem now is we have to see if that is
#because they released the most movies during that time frame or were they on par for the same amount of realeases
#as the other months

# %%
#Time to scrape some more data to get the total releases per month for calendar years 2018 and 2019

# %%
page3 = requests.get('https://www.boxofficemojo.com/month/by-year/2018/?grossesOption=calendarGrosses')
page3
# Out:
# <Response [200]>

# %%
page3.status_code
# Out:
# 200

# %%
page3.content
# Out:
# b'<!doctype html><html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1.0" />\n                <meta charset="utf-8" />\n            <title dir="ltr">2018 Monthly Box Office - Box Office Mojo</title><meta content="2018 Monthly Box Office" name="title" />\n            <meta content="Box Office Mojo" property="og:site_name" />\n            <meta content="https://m.media-amazon.com/images/G/01/boxofficemojo/logo/mojo-logo-bg.png" property="og:image"/>\n            <meta name="format-detection" content="telephone=no" />\n            <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" type="image/x-icon" rel="icon" />\n            <link rel="canonical" href="https://www.boxofficemojo.com/month/by-year/2018/?grossesOption=calendarGrosses" />\n            <link rel="stylesheet" href="https://images-na.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|01ZTHTZObnL.css,41DAFIecsVL.css,51IB+wfP8qL.css,01ZfXnjPmmL.css,01oDR3IULNL.css,01Vctty9pOL.css,31ZcpBfSgNL.css,01XPHJk60-L.css,21qPwhPKAAL.css,01R0k0yxPXL.css,21xVR0NtxzL.css,11gneA3MtJL.css,21fecG8pUzL.css,01RddH8vm-L.css,01CFUgsA-YL.css,21AmhU6t0sL.css,11zGrJZ9D2L.css,11tRp6+0HHL.css,11061HxnEvL.css,11oHt2HYxnL.css,01-fWz3sOQL.css,11ocrgKoE-L.css,11RKoGSb-gL.css,11g1xm90ZvL.css,01QrWuRrZ-L.css,21pIv-yKhaL.css,01Wiow6micL.css,01gAR5pB+IL.css,119dKrtBoVL.css,11Y05DTEL6L.css,01cbS3UK11L.css,21F85am0yFL.css,01giMEP+djL.css_.css?AUIClients/AmazonUI#us.not-trident" />\n<link rel="stylesheet" href="https://images-na.ssl-images-amazon.com/images/I/51e2aUsLp9L.css?AUIClients/IMDbMojoSiteAssets" />\n<script>\n(function(f,h,Q,E){function F(a){u&&u.tag&&u.tag(q(":","aui",a))}function v(a,b){u&&u.count&&u.count("aui:"+a,0===b?0:b||(u.count("aui:"+a)||0)+1)}function m(a){try{return a.test(navigator.userAgent)}catch(b){return!1}}function x(a,b,c){a.addEventListener?a.addEventListener(b,c,!1):a.attachEvent&&a.attachEvent("on"+b,c)}function q(a,b,c,e){b=b&&c?b+a+c:b||c;return e?q(a,b,e):b}function G(a,b,c){try{Object.defineProperty(a,b,{value:c,writable:!1})}catch(e){a[b]=c}return c}function ta(a,b){var c=a.length,\ne=c,g=function(){e--||(R.push(b),S||(setTimeout(ca,0),S=!0))};for(g();c--;)da[a[c]]?g():(z[a[c]]=z[a[c]]||[]).push(g)}function ua(a,b,c,e,g){var d=h.createElement(a?"script":"link");x(d,"error",e);g&&x(d,"load",g);a?(d.type="text/javascript",d.async=!0,c&&/AUIClients|images[/]I/.test(b)&&d.setAttribute("crossorigin","anonymous"),d.src=b):(d.rel="stylesheet",d.href=b);h.getElementsByTagName("head")[0].appendChild(d)}function ea(a,b){return function(c,e){function g(){ua(b,c,d,function(b){T?v("resource_unload"):\nd?(d=!1,v("resource_retry"),g()):(v("resource_error"),a.log("Asset failed to load: "+c));b&&b.stopPropagation?b.stopPropagation():f.event&&(f.event.cancelBubble=!0)},e)}if(fa[c])return!1;fa[c]=!0;v("resource_count");var d=!0;return!g()}}function va(a,b,c){for(var e={name:a,guard:function(c){return b.guardFatal(a,c)},guardTime:function(a){return b.guardTime(a)},logError:function(c,d,e){b.logError(c,d,e,a)}},g=[],d=0;d<c.length;d++)H.hasOwnProperty(c[d])&&(g[d]=U.hasOwnProperty(c[d])?U[c[d]](H[c[d]],\ne):H[c[d]]);return g}function A(a,b,c,e,g){return function(d,h){function n(){var a=null;e?a=h:"function"===typeof h&&(p.start=w(),a=h.apply(f,va(d,k,l)),p.end=w());if(b){H[d]=a;a=d;for(da[a]=!0;(z[a]||[]).length;)z[a].shift()();delete z[a]}p.done=!0}var k=g||this;"function"===typeof d&&(h=d,d=E);b&&(d=d?d.replace(ha,""):"__NONAME__",V.hasOwnProperty(d)&&k.error(q(", reregistered by ",q(" by ",d+" already registered",V[d]),k.attribution),d),V[d]=k.attribution);for(var l=[],m=0;m<a.length;m++)l[m]=\na[m].replace(ha,"");var p=B[d||"anon"+ ++wa]={depend:l,registered:w(),namespace:k.namespace};c?n():ta(l,k.guardFatal(d,n));return{decorate:function(a){U[d]=k.guardFatal(d,a)}}}}function ia(a){return function(){var b ...

# %%
url3 = "https://www.boxofficemojo.com/month/by-year/2018/?grossesOption=calendarGrosses"
page3=requests.get(url3)
soup3 = BS(page3.content, 'html.parser')
url4 = "https://www.boxofficemojo.com/month/by-year/2019/?grossesOption=calendarGrosses"
page4=requests.get(url4)
soup4 = BS(page4.content, 'html.parser')

# %%
months = soup3.find_all(class_='a-text-left mojo-header-column mojo-truncate mojo-field-type-named_interval mojo-sort-column')
months[0].get_text()
# Out:
# 'December'

# %%
months = soup4.find_all(class_='a-text-left mojo-header-column mojo-truncate mojo-field-type-named_interval mojo-sort-column')
months[0].get_text()
# Out:
# 'December'

# %%
month_list_2018 = []
for i in months:
    month_list_2018.append(i.get_text())
month_list_2018
# Out:
# ['December',
#  'November',
#  'October',
#  'September',
#  'August',
#  'July',
#  'June',
#  'May',
#  'April',
#  'March',
#  'February',
#  'January']

# %%
month_list_2019 = []
for i in months:
    month_list_2019.append(i.get_text())
month_list_2019
# Out:
# ['December',
#  'November',
#  'October',
#  'September',
#  'August',
#  'July',
#  'June',
#  'May',
#  'April',
#  'March',
#  'February',
#  'January']

# %%
amount_of_realeases = soup3.find_all(class_='a-text-right mojo-field-type-positive_integer')
amount_of_realeases[0].get_text()
# Out:
# '188'

# %%
amount_of_realeases = soup4.find_all(class_='a-text-right mojo-field-type-positive_integer')
amount_of_realeases[0].get_text()
# Out:
# '167'

# %%
amount_of_realeases_2018 =[]
for i in amount_of_realeases:
    amount_of_realeases_2018.append(i.get_text())
amount_of_realeases_2018
# Out:
# ['188',
#  '241',
#  '242',
#  '235',
#  '217',
#  '198',
#  '211',
#  '218',
#  '225',
#  '225',
#  '185',
#  '154']

# %%
amount_of_realeases_2019 =[]
for i in amount_of_realeases:
    amount_of_realeases_2019.append(i.get_text())
amount_of_realeases_2019
# Out:
# ['167',
#  '189',
#  '217',
#  '204',
#  '211',
#  '190',
#  '193',
#  '225',
#  '220',
#  '192',
#  '147',
#  '161']

# %%
number_of_releases = pd.DataFrame(list(zip(month_list_2018, amount_of_realeases_2018, amount_of_realeases_2019,)),
                           columns =['Months','Releases_in_2018', 'Releases_in_2019', ])
number_of_releases
# Out:
#        Months Releases_in_2018 Releases_in_2019
# 0    December              188              167
# 1    November              241              189
# 2     October              242              217
# 3   September              235              204
# 4      August              217              211
# 5        July              198              190
# 6        June              211              193
# 7         May              218              225
# 8       April              225              220
# 9       March              225              192
# 10   February              185              147
# 11    January              154              161

# %%
topGrossingValues = pd.DataFrame(list(zip(top_grossing_2018, top_grossing_2019)),
                           columns =['Releases_in_2018', 'Releases_in_2019', ])
topGrossingValues
# Out:
#     Releases_in_2018  Releases_in_2019
# 0                 29                26
# 1                 26                26
# 2                 20                22
# 3                 19                18
# 4                 17                18
# 5                 17                16
# 6                 14                15
# 7                 14                15
# 8                 12                12
# 9                 12                12
# 10                11                10
# 11                 9                10

# %%
topGrossingValues2019 = pd.DataFrame(top_grossing_2019)
topGrossingValues2018= pd.DataFrame(top_grossing_2018)
topGrossingValues2018.reset_index(inplace =True)
topGrossingValues2019.reset_index(inplace = True)
topGrossingValues2018.rename(columns ={'index':'Months'}, inplace = True)
topGrossingValues2019.rename(columns ={'index':'Months'}, inplace = True)
tgv18_19 = topGrossingValues2018.merge(topGrossingValues2019, on = 'Months',)
tgv18_19
# Out:
#    Months  Realease_Date_x  Realease_Date_y
# 0     Dec               29               26
# 1     Nov               26               26
# 2     Mar               20               15
# 3     Aug               19               22
# 4     Sep               17               12
# 5     Jun               17               15
# 6     Oct               14               18
# 7     Apr               14               12
# 8     May               12               18
# 9     Jul               12               10
# 10    Feb               11               16
# 11    Jan                9               10

# %%
number_of_releases['Months']=number_of_releases['Months'].map(lambda x: str(x)[0:3])
releases = number_of_releases.merge(tgv18_19,on ='Months')
releases['Releases_in_2018'] = releases['Releases_in_2018'].astype(int)
releases['Releases_in_2019'] = releases['Releases_in_2019'].astype(int)
releases['sum_of_releases'] = releases['Releases_in_2018'] +releases['Releases_in_2019']
releases['sum_of_top_grossing'] = releases['Realease_Date_x'] + releases['Realease_Date_y']
releases['percent_of_top_grossing_movies_released'] = round((releases['sum_of_top_grossing']/releases['sum_of_releases'])*100,2)
releases
# Out:
#    Months  Releases_in_2018  Releases_in_2019  Realease_Date_x  \
# 0     Dec               188               167               29
# 1     Nov               241               189               26
# 2     Oct               242               217               14
# 3     Sep               235               204               17
# 4     Aug               217               211               19
# 5     Jul               198               190               12
# 6     Jun               211               193               17
# 7     May               218               225               12
# 8     Apr               225               220               14
# 9     Mar               225               192               20
# 10    Feb               185               147               11
# 11    Jan               154               161                9
#
#     Realease_Date_y  sum_of_releases  sum_of_top_grossing  \
# 0                26              355                   55
# 1                26              430                   52
# 2                18              459                   32
# 3                12              439                   29
# 4                22              428                   41
# 5                10              388                   22
# 6                15              404                   32
# 7                18              443                   30
# 8                12              445                   26
# 9                15              417                   35
# 10               16              332                   27
# 11               10              315                   19
#
#     percent_of_top_grossing_movies_released
# 0                                     15.49
# 1                                     12.09
# 2                                      6.97
# 3                                      6.61
# 4                                      9.58
# 5                                      5.67
# 6                                      7.92
# 7                                      6.77
# 8                                      5.84
# 9                                      8.39
# 10                                     8.13
# 11                                     6.03

# %%
fig, ax =plt.subplots(figsize=(20,10))
ax.bar(releases['Months'],height = releases['percent_of_top_grossing_movies_released'])
ax.set_ylim(0,20)

for index,data in enumerate(releases['percent_of_top_grossing_movies_released']):
    plt.text(x=index , y =data+.1 , s=f"{data}"+'%' , fontdict=dict(fontsize=10))

# %%
top_grossing_2018 = movies_2018['Realease_Date'].value_counts()
top_grossing_2019 = movies_2019['Realease_Date'].value_counts()
top_grossing_2018
# Out:
# Dec    29
# Nov    26
# Mar    20
# Aug    19
# Sep    17
# Jun    17
# Oct    14
# Apr    14
# May    12
# Jul    12
# Feb    11
# Jan     9
# Name: Realease_Date, dtype: int64
