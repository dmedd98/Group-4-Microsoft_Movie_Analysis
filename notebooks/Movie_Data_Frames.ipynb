# %%
pwd
# Out:
# '/Users/dillmedd/Documents/Flatiron/Group Project/Group-4-Microsoft_Movie_Analysis/notebooks'

# %%
ls
# Out:
# CONTRIBUTING.md                    code/
# DS_Project_Presentation.pdf        data/
# LICENSE.md                         dsc-phase1-project-template.ipynb
# Movie Data Frames.ipynb            images/
# README.md                          notebooks/
# TEMPLATE_README.md

# %%
cd data
# Out:
# /Users/dillmedd/Documents/Flatiron/Group Project/Group-4-Microsoft_Movie_Analysis/data

# %%
cd zippedData
# Out:
# /Users/dillmedd/Documents/Flatiron/Group Project/Group-4-Microsoft_Movie_Analysis/data/zippedData

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df_name_basics = pd.read_csv('imdb.name.basics.csv.gz')
df_name_basics
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606643                                           actress
# 606644                                           actress
# 606645                                           actress
# 606646                                          producer
# 606647                             director,actor,writer
#
#                                known_for_titles
# 0       tt0837562,tt2398241,tt0844471,tt0118553
# 1       tt0896534,tt6791238,tt0287072,tt1682940
# 2       tt1470654,tt0363631,tt0104030,tt0102898
# 3       tt0114371,tt2004304,tt1618448,tt1224387
# 4       tt0452644,tt0452692,tt3458030,tt2178256
# ...                                         ...
# 606643                                      NaN
# 606644                      tt9090932,tt8737130
# 606645                      tt8734436,tt9615610
# 606646                                      NaN
# 606647                                tt8743182
#
# [606648 rows x 6 columns]

# %%
df_title_akas = pd.read_csv('imdb.title.akas.csv.gz')
df_title_akas
# Out:
#          title_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru    NaN
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención    NaN
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
#        language        types   attributes  is_original_title
# 0            bg          NaN          NaN                0.0
# 1           NaN  imdbDisplay          NaN                0.0
# 2           NaN  imdbDisplay          NaN                0.0
# 3           NaN          NaN  short title                0.0
# 4           NaN  imdbDisplay          NaN                0.0
# ...         ...          ...          ...                ...
# 331698      NaN     original          NaN                1.0
# 331699       en  imdbDisplay          NaN                0.0
# 331700      NaN     original          NaN                1.0
# 331701      NaN          NaN          NaN                0.0
# 331702       en  imdbDisplay          NaN                0.0
#
# [331703 rows x 8 columns]

# %%
df_title_akas['attributes'].value_counts().head(15)
# Out:
# new title                           1700
# alternative spelling                1394
# literal English title               1054
# complete title                      1034
# original subtitled version           879
# informal English title               816
# transliterated ISO-LATIN-1 title     695
# dubbed version                       645
# short title                          640
# alternative transliteration          611
# DVD box title                        601
# literal title                        490
# original script title                300
# 3-D version                          292
# promotional title                    285
# Name: attributes, dtype: int64

# %%
df_title_basics = pd.read_csv('imdb.title.basics.csv.gz')
df_title_basics
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                   NaN
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
df_imdb = df_title_basics.merge(df_title_ratings, left_on = 'tconst', right_on = 'tconst')

# %%
df_imdb = df_imdb.dropna()

# %%
df_imdb
# Out:
#           tconst                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 6      tt0137204                  Joe Finds Grace             Joe Finds Grace
# ...          ...                              ...                         ...
# 73849  tt9911774        Padmavyuhathile Abhimanyu   Padmavyuhathile Abhimanyu
# 73850  tt9913056                     Swarm Season                Swarm Season
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73855  tt9916160                       Drømmeland                  Drømmeland
#
#        start_year  runtime_minutes                      genres  averagerating  \
# 0            2013            175.0          Action,Crime,Drama            7.0
# 1            2019            114.0             Biography,Drama            7.2
# 2            2018            122.0                       Drama            6.9
# 4            2017             80.0        Comedy,Drama,Fantasy            6.5
# 6            2017             83.0  Adventure,Animation,Comedy            8.1
# ...           ...              ...                         ...            ...
# 73849        2019            130.0                       Drama            8.4
# 73850        2019             86.0                 Documentary            6.2
# 73851        2019             75.0                 Documentary            6.2
# 73852        2019             98.0                Drama,Family            8.7
# 73855        2019             72.0                 Documentary            6.5
#
#        numvotes
# 0            77
# 1            43
# 2          4517
# 4           119
# 6           263
# ...         ...
# 73849       365
# 73850         5
# 73851         6
# 73852       136
# 73855        11
#
# [65720 rows x 8 columns]

# %%
df_title_basics['genres'].value_counts().head(10)
# Out:
# Documentary              32185
# Drama                    21486
# Comedy                    9177
# Horror                    4372
# Comedy,Drama              3519
# Thriller                  3046
# Action                    2219
# Biography,Documentary     2115
# Drama,Romance             2079
# Comedy,Drama,Romance      1558
# Name: genres, dtype: int64

# %%
df_coms = df_imdb[df_imdb['genres'] == 'Comedy']

# %%
df_coms = df_coms.loc[df_coms['numvotes'] > 500]

# %%
df_docs = df_imdb[df_imdb['genres'] == 'Documentary']

# %%
df_docs = df_docs.loc[df_docs['numvotes'] > 500]

# %%
df_thriller = df_imdb[df_imdb['genres'] == 'Thriller']

# %%
df_thriller = df_thriller.loc[df_thriller['numvotes'] > 500]

# %%
from matplotlib import pyplot as plt

# %%
fig, ax = plt.subplots()

ax.scatter(df_coms['runtime_minutes'], df_coms['averagerating'])
ax.set_xlabel('Runtime(minutes)')
ax.set_ylabel('Movie Rating')
ax.set_xlim([40,250])
# Out:
# (40.0, 250.0)

# %%
fig, ax = plt.subplots()

ax.scatter(df_docs['runtime_minutes'], df_docs['averagerating'])
ax.set_xlabel('Runtime(minutes)')
ax.set_ylabel('Movie Rating')
ax.set_xlim([40,250])
# Out:
# (40.0, 250.0)

# %%
fig, ax = plt.subplots()

ax.scatter(df_thriller['runtime_minutes'], df_thriller['averagerating'])
ax.set_xlabel('Runtime(minutes)')
ax.set_ylabel('Movie Rating')
ax.set_xlim([50,200])
# Out:
# (50.0, 200.0)

# %%
df_title_crew = pd.read_csv('imdb.title.crew.csv.gz')
df_title_crew
# Out:
#            tconst                      directors              writers
# 0       tt0285252                      nm0899854            nm0899854
# 1       tt0438973                            NaN  nm0175726,nm1802864
# 2       tt0462036                      nm1940585            nm1940585
# 3       tt0835418                      nm0151540  nm0310087,nm0841532
# 4       tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
# ...           ...                            ...                  ...
# 146139  tt8999974                     nm10122357           nm10122357
# 146140  tt9001390                      nm6711477            nm6711477
# 146141  tt9001494          nm10123242,nm10123248                  NaN
# 146142  tt9004986                      nm4993825            nm4993825
# 146143  tt9010172                            NaN            nm8352242
#
# [146144 rows x 3 columns]

# %%
df_title_princ = pd.read_csv('imdb.title.principals.csv.gz')
df_title_princ
# Out:
#             tconst  ordering      nconst  category       job  \
# 0        tt0111414         1   nm0246005     actor       NaN
# 1        tt0111414         2   nm0398271  director       NaN
# 2        tt0111414         3   nm3739909  producer  producer
# 3        tt0323808        10   nm0059247    editor       NaN
# 4        tt0323808         1   nm3579312   actress       NaN
# ...            ...       ...         ...       ...       ...
# 1028181  tt9692684         1   nm0186469     actor       NaN
# 1028182  tt9692684         2   nm4929530      self       NaN
# 1028183  tt9692684         3  nm10441594  director       NaN
# 1028184  tt9692684         4   nm6009913    writer    writer
# 1028185  tt9692684         5  nm10441595  producer  producer
#
#                    characters
# 0                 ["The Man"]
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4            ["Beth Boothby"]
# ...                       ...
# 1028181  ["Ebenezer Scrooge"]
# 1028182   ["Herself","Regan"]
# 1028183                   NaN
# 1028184                   NaN
# 1028185                   NaN
#
# [1028186 rows x 6 columns]

# %%
df_title_ratings = pd.read_csv('imdb.title.ratings.csv.gz')
df_title_ratings
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
df_title_ratings.describe()
# Out:
#        averagerating      numvotes
# count   73856.000000  7.385600e+04
# mean        6.332729  3.523662e+03
# std         1.474978  3.029402e+04
# min         1.000000  5.000000e+00
# 25%         5.500000  1.400000e+01
# 50%         6.500000  4.900000e+01
# 75%         7.400000  2.820000e+02
# max        10.000000  1.841066e+06

# %%
df_movie_gross = pd.read_csv('bom.movie_gross.csv.gz')
df_movie_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
df_rt_info = pd.read_csv('rt.movie_info.tsv.gz', sep = '\t')
df_rt_info
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
# [1560 rows x 12 columns]

# %%
df_rt_info2 = df_rt_info.dropna()

# %%
df_rt_info2['minute_count'] = df_rt_info2['runtime'].split(' ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-4de0a3eb76be> in <module>
# ----> 1 df_rt_info2['minute_count'] = df_rt_info2['runtime'].split(' ')
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
fig, ax = plt.subplots()

ax.scatter(df_rt_info2['runtime'], df_rt_info2['box_office'])
ax.set_xlabel('Runtime(minutes)')
ax.set_ylabel('Box Office $')
ax.set_xlim([0,250])
# Out:
# (0.0, 250.0)

# %%
df_rt_review = pd.read_csv('rt.reviews.tsv.gz', sep = '\t', encoding = 'unicode_escape')
df_rt_review
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
#                   critic  top_critic         publisher                date
# 0             PJ Nabarro           0   Patrick Nabarro   November 10, 2018
# 1         Annalee Newitz           0           io9.com        May 23, 2018
# 2           Sean Axmaker           0  Stream on Demand     January 4, 2018
# 3          Daniel Kasman           0              MUBI   November 16, 2017
# 4                    NaN           0      Cinema Scope    October 12, 2017
# ...                  ...         ...               ...                 ...
# 54427      Laura Sinagra           1     Village Voice  September 24, 2002
# 54428  Michael Szymanski           0        Zap2it.com  September 21, 2005
# 54429       Emanuel Levy           0   EmanuelLevy.Com       July 17, 2005
# 54430   Christopher Null           0    Filmcritic.com   September 7, 2003
# 54431    Nicolas Lacroix           0      Showbizz.net   November 12, 2002
#
# [54432 rows x 8 columns]

# %%
df_tmdb = pd.read_csv('tmdb.movies.csv.gz')
df_tmdb
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %%
df_budgets = pd.read_csv('tn.movie_budgets.csv.gz')
df_budgets.head(30)
# Out:
#     id  release_date                                             movie  \
# 0    1  Dec 18, 2009                                            Avatar
# 1    2  May 20, 2011       Pirates of the Caribbean: On Stranger Tides
# 2    3   Jun 7, 2019                                      Dark Phoenix
# 3    4   May 1, 2015                           Avengers: Age of Ultron
# 4    5  Dec 15, 2017                 Star Wars Ep. VIII: The Last Jedi
# 5    6  Dec 18, 2015              Star Wars Ep. VII: The Force Awakens
# 6    7  Apr 27, 2018                            Avengers: Infinity War
# 7    8  May 24, 2007        Pirates of the Caribbean: At Worldâs End
# 8    9  Nov 17, 2017                                    Justice League
# 9   10   Nov 6, 2015                                           Spectre
# 10  11  Jul 20, 2012                             The Dark Knight Rises
# 11  12  May 25, 2018                           Solo: A Star Wars Story
# 12  13   Jul 2, 2013                                   The Lone Ranger
# 13  14   Mar 9, 2012                                       John Carter
# 14  15  Nov 24, 2010                                           Tangled
# 15  16   May 4, 2007                                      Spider-Man 3
# 16  17   May 6, 2016                        Captain America: Civil War
# 17  18  Mar 25, 2016                Batman v Superman: Dawn of Justice
# 18  19  Dec 14, 2012                 The Hobbit: An Unexpected Journey
# 19  20  Jul 15, 2009            Harry Potter and the Half-Blood Prince
# 20  21  Dec 13, 2013               The Hobbit: The Desolation of Smaug
# 21  22  Dec 17, 2014         The Hobbit: The Battle of the Five Armies
# 22  23  Apr 14, 2017                           The Fate of the Furious
# 23  24  Jun 28, 2006                                  Superman Returns
# 24  25  May 26, 2017  Pirates of the Caribbean: Dead Men Tell No Tales
# 25  26  Nov 14, 2008                                 Quantum of Solace
# 26  27   May 4, 2012                                      The Avengers
# 27  28   Jul 7, 2006      Pirates of the Caribbean: Dead Manâs Chest
# 28  29  Jun 14, 2013                                      Man of Steel
# 29  30  May 16, 2008          The Chronicles of Narnia: Prince Caspian
#
#    production_budget domestic_gross worldwide_gross
# 0       $425,000,000   $760,507,625  $2,776,345,279
# 1       $410,600,000   $241,063,875  $1,045,663,875
# 2       $350,000,000    $42,762,350    $149,762,350
# 3       $330,600,000   $459,005,868  $1,403,013,963
# 4       $317,000,000   $620,181,382  $1,316,721,747
# 5       $306,000,000   $936,662,225  $2,053,311,220
# 6       $300,000,000   $678,815,482  $2,048,134,200
# 7       $300,000,000   $309,420,425    $963,420,425
# 8       $300,000,000   $229,024,295    $655,945,209
# 9       $300,000,000   $200,074,175    $879,620,923
# 10      $275,000,000   $448,139,099  $1,084,439,099
# 11      $275,000,000   $213,767,512    $393,151,347
# 12      $275,000,000    $89,302,115    $260,002,115
# 13      $275,000,000    $73,058,679    $282,778,100
# 14      $260,000,000   $200,821,936    $586,477,240
# 15      $258,000,000   $336,530,303    $894,860,230
# 16      $250,000,000   $408,084,349  $1,140,069,413
# 17      $250,000,000   $330,360,194    $867,500,281
# 18      $250,000,000   $303,003,568  $1,017,003,568
# 19      $250,000,000   $302,089,278    $935,213,767
# 20      $250,000,000   $258,366,855    $960,366,855
# 21      $250,000,000   $255,119,788    $945,577,621
# 22      $250,000,000   $225,764,765  $1,234,846,267
# 23      $232,000,000   $200,120,000    $374,085,065
# 24      $230,000,000   $172,558,876    $788,241,137
# 25      $230,000,000   $169,368,427    $591,692,078
# 26      $225,000,000   $623,279,547  $1,517,935,897
# 27      $225,000,000   $423,315,812  $1,066,215,812
# 28      $225,000,000   $291,045,518    $667,999,518
# 29      $225,000,000   $141,621,490    $417,341,288

# %%
df_budgets['production_budget'] = df_budgets['production_budget'].str.replace('$','')

# %%
df_budgets['domestic_gross'] = df_budgets['domestic_gross'].str.replace('$','')

# %%
df_budgets['worldwide_gross'] = df_budgets['worldwide_gross'].str.replace('$','')

# %%
df_budgets['production_budget'] = df_budgets['production_budget'].str.replace(',','')

# %%
df_budgets['domestic_gross'] = df_budgets['domestic_gross'].str.replace(',','')
df_budgets['worldwide_gross'] = df_budgets['worldwide_gross'].str.replace(',','')

# %%
df_budgets['production_budget'] = df_budgets['production_budget'].astype(int)
df_budgets['domestic_gross'] = df_budgets['domestic_gross'].astype(int)
df_budgets['worldwide_gross'] = df_budgets['worldwide_gross'].astype(int)

df_budgets['total_profit'] = df_budgets['worldwide_gross'] - df_budgets['production_budget']

# %%
df_budgets['year'] = pd.DatetimeIndex(df_budgets['release_date']).year

# %%
df_budgets = df_budgets.loc[df_budgets['year'] >= 2010]

# %%
df_budgets['ROI %'] = (df_budgets['total_profit'] / df_budgets['production_budget']) * 100

# %%
df_highbudget = df_budgets.loc[df_budgets['production_budget'] >= 150000000]

# %%
no_high = df_budgets.loc[df_budgets['production_budget'] < 150000000]

df_medbudget = no_high.loc[no_high['production_budget'] >= 90000000]

no_med = no_high[no_high['production_budget'] < 90000000]

# %%
df_lowerbudget = no_med.loc[no_med['production_budget'] >= 40000000]

# %%
df_above20mil = df_budgets.loc[df_budgets['production_budget'] > 20000000]

# %%
df_above20mil
# Out:
#       id  release_date                                        movie  \
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# 5      6  Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
# ...   ..           ...                                          ...
# 2471  72   Dec 9, 2011                    Tinker Tailor Soldier Spy
# 2472  73  Sep 22, 2017                           Victoria and Abdul
# 2478  79   May 6, 2011                                   The Beaver
# 2479  80  Feb 24, 2017                               Bitter Harvest
# 2481  82   Feb 1, 2019                               Velvet Buzzsaw
#
#       production_budget  domestic_gross  worldwide_gross  total_profit  year  \
# 1             410600000       241063875       1045663875     635063875  2011
# 2             350000000        42762350        149762350    -200237650  2019
# 3             330600000       459005868       1403013963    1072413963  2015
# 4             317000000       620181382       1316721747     999721747  2017
# 5             306000000       936662225       2053311220    1747311220  2015
# ...                 ...             ...              ...           ...   ...
# 2471           21000000        24149393         81452811      60452811  2011
# 2472           21000000        22245070         68271146      47271146  2017
# 2478           21000000          970816          5046038     -15953962  2011
# 2479           21000000          557241           606162     -20393838  2017
# 2481           21000000               0                0     -21000000  2019
#
#            ROI %
# 1     154.667286
# 2     -57.210757
# 3     324.384139
# 4     315.369636
# 5     571.016739
# ...          ...
# 2471  287.870529
# 2472  225.100695
# 2478  -75.971248
# 2479  -97.113514
# 2481 -100.000000
#
# [948 rows x 9 columns]

# %%
plt.hist(df_above20mil['production_budget'], bins = 25)
# Out:
# (array([305., 187.,  93.,  72.,  42.,  47.,  45.,  21.,  35.,  29.,  22.,
#          21.,   7.,   3.,   6.,   1.,   4.,   3.,   2.,   1.,   0.,   1.,
#           0.,   0.,   1.]),
#  array([2.10000e+07, 3.65840e+07, 5.21680e+07, 6.77520e+07, 8.33360e+07,
#         9.89200e+07, 1.14504e+08, 1.30088e+08, 1.45672e+08, 1.61256e+08,
#         1.76840e+08, 1.92424e+08, 2.08008e+08, 2.23592e+08, 2.39176e+08,
#         2.54760e+08, 2.70344e+08, 2.85928e+08, 3.01512e+08, 3.17096e+08,
#         3.32680e+08, 3.48264e+08, 3.63848e+08, 3.79432e+08, 3.95016e+08,
#         4.10600e+08]),
#  <BarContainer object of 25 artists>)

# %%
df_budgets.sort_values(by=['ROI %'], ascending = False).head(40)
# Out:
#       id  release_date                       movie  production_budget  \
# 5679  80  Jul 10, 2015                 The Gallows             100000
# 5211  12   Jan 6, 2012            The Devil Inside            1000000
# 5062  63   Apr 1, 2011                   Insidious            1500000
# 5213  14  Apr 17, 2015                  Unfriended            1000000
# 4664  65  Oct 20, 2010       Paranormal Activity 2            3000000
# 4254        67268835        148806510     143806510  2016   2876.130200
# 4668        48086903         87727807      84727807  2012   2824.260233
# 2996       138797449        430821168     415821168  2010   2772.141120
# 4258        53900335        142817992     137817992  2012   2756.359840
# 5685         1594798          2769782       2669782  2017   2669.782000
# 4590        41411015         95127344      91627344  2018   2617.924114
# 5216        18494006         26887177      25887177  2013   2588.717700
# 5672         1597486          3090593       2970593  2012   2475.494167
# 3342       124872350        307166834     295166834  2014   2459.723617
# 3535       159342015        254900667     244900667  2018   2449.006670
# 3245       106954678        331266710     318266710  2010   2448.205462
# 4257        55683845        125010260     120010260  2017   2400.205200
# 4665        67790117         73975239      70975239  2015   2365.841300
# 3987       113721571        170549753     163549753  2012   2336.425043
# 4811        40041683         59922558      57422558  2013   2296.902320
# 4253        72082999        108286422     103286422  2016   2065.728440
# 2491       151101803        426351163     406351163  2016   2031.755815
# 4259        50856010        103300632      98300632  2014   1966.012640
# 3001       102092201        305384865     290384865  2017   1935.899100
# 4261        44467206        100486616      95486616  2013   1909.732320
# 1623       327481748        697457969     662457969  2017   1892.737054
# 4255        65206105         98677816      93677816  2015   1873.556320

# %%
fig, ax = plt.subplots(figsize = (8, 8))

plt.scatter(df_budgets['production_budget'], df_budgets['ROI %'])
plt.xlabel('Budget (in 100s of millions)')
plt.ylabel('ROI %')
plt.axhline(y=0, color='r', linestyle='-')
plt.axhline(y=200, color='g', linestyle='-');

# %%
df_highbudget.sort_values(by=['ROI %'], ascending = False).head(50)
# Out:
#       id  release_date                                    movie  \
# 155   56  Nov 22, 2013                                   Frozen
# 66    67   Apr 3, 2015                                Furious 7
# 134   35  Mar 17, 2017                     Beauty and the Beast
# 112   13  Jun 22, 2018           Jurassic World: Fallen Kingdom
# 33    34  Jun 12, 2015                           Jurassic World
# 135   36  Dec 21, 2018                                  Aquaman
# 6      7  Apr 27, 2018                   Avengers: Infinity War
# 156   57   Mar 4, 2016                                 Zootopia
# 26    27   May 4, 2012                             The Avengers
# 41    42  Feb 16, 2018                            Black Panther
# 5      6  Dec 18, 2015     Star Wars Ep. VII: The Force Awakens
# 95    96   Mar 8, 2019                           Captain Marvel
# 43    44  Jun 15, 2018                            Incredibles 2
# 47    48   May 3, 2013                               Iron Man 3
# 63    64  Jun 29, 2011           Transformers: Dark of the Moon
# 51    52   Nov 8, 2012                                  Skyfall
# 96    97  Apr 15, 2016                          The Jungle Book
# 154   55   Jun 2, 2017                             Wonder Woman
# 46    47  Jun 18, 2010                              Toy Story 3
# 36    37  Jun 27, 2014          Transformers: Age of Extinction
# 44    45  Dec 16, 2016             Rogue One: A Star Wars Story
# 137   38  Jul 16, 2010                                Inception
# 50    51   Mar 5, 2010                      Alice in Wonderland
# 45    46  Jun 17, 2016                             Finding Dory
# 98    99   Jul 7, 2017                   Spider-Man: Homecoming
# 22    23  Apr 14, 2017                  The Fate of the Furious
# 139   40  May 24, 2013                       Fast and Furious 6
# 97    98  Jun 19, 2015                               Inside Out
# 165          150000000       206362140        644602516     494602516  2013
# 99           175000000       325100054        746059887     571059887  2016
# 161          150000000       248757044        637517365     487517365  2016
# 3            330600000       459005868       1403013963    1072413963  2015
# 83           180000000       241407328        758536735     578536735  2014
# 115          170000000       259746958        714401889     544401889  2014
# 116          170000000       208545589        710644566     540644566  2014
# 4            317000000       620181382       1316721747     999721747  2017
# 127          165000000       232641920        676404566     511404566  2016
# 18           250000000       303003568       1017003568     767003568  2012
# 138          160000000       281723902        648986787     488986787  2015
# 131          165000000       188017894        666379375     501379375  2014
#
#           ROI %
# 155  748.313273
# 66   699.327786
# 134  686.999816
# 112  668.101646
# 33   666.909239
# 135  616.809150
# 6    582.711400
# 156  579.619744
# 26   574.638176
# 41   574.129112
# 5    571.016739
# 95   541.749457
# 43   521.260356
# 47   507.696136
# 63   476.302843
# 51   455.263490
# 96   450.202598
# 154  447.422252
# 46   434.439761
# 36   425.732893
# 44   424.551428
# 137  422.202901
# 50   412.745555
# 45   410.607596
# 98   402.952200
# 22   393.938507
# 139  393.312777
# 97   388.134853
# 81   370.544458
# 167  359.239328
# 126  358.330105
# 16   356.027765
# 101  356.004629
# 113  353.451480
# 84   345.779363
# 173  343.225031
# 91   342.391321
# 48   331.158117
# 165  329.735011
# 99   326.319935
# 161  325.011577
# 3    324.384139
# 83   321.409297
# 115  320.236405
# 116  318.026215
# 4    315.369636
# 127  309.942161
# 18   306.801427
# 138  305.616742
# 131  303.866288

# %%
df_highbudget['is_sci-fi'] = False
# Out:
# <ipython-input-27-7f7fadd4876a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_highbudget['is_sci-fi'] = False

# %%
df_highbudget.sort_values(by=['ROI %'], ascending = False)[30:65]
# Out:
#       id  release_date                                             movie  \
# 126   27  May 21, 2010                               Shrek Forever After
# 16    17   May 6, 2016                        Captain America: Civil War
# 101    2  Nov 22, 2017                                              Coco
# 113   14   Aug 1, 2014                           Guardians of the Galaxy
# 84    85  Nov 18, 2016           Fantastic Beasts and Where to Find Them
# 173   74  May 26, 2011                                   Kung Fu Panda 2
# 91    92  Jul 27, 2018                     Mission: ImpossibleâFallout
# 48    49   May 5, 2017                     Guardians of the Galaxy Vol 2
# 165   66   Nov 8, 2013                              Thor: The Dark World
# 99   100   Aug 5, 2016                                     Suicide Squad
# 161   62  Nov 23, 2016                                             Moana
# 3      4   May 1, 2015                           Avengers: Age of Ultron
# 83    84  May 30, 2014                                        Maleficent
# 115   16   Apr 4, 2014               Captain America: The Winter Soldier
# 116   17  Jul 11, 2014                    Dawn of the Planet of the Apes
# 4      5  Dec 15, 2017                 Star Wars Ep. VIII: The Last Jedi
# 127   28   Nov 4, 2016                                    Doctor Strange
# 18    19  Dec 14, 2012                 The Hobbit: An Unexpected Journey
# 138   39  Nov 20, 2015             The Hunger Games: Mockingjay - Part 2
# 131   32   Nov 5, 2014                                      Interstellar
# 128   29   Nov 7, 2014                                        Big Hero 6
# 10    11  Jul 20, 2012                             The Dark Knight Rises
# 177   78  Mar 29, 2018                                  Ready Player One
# 140  230.672543      False

# %%
import numpy as np

# %%
sf_movies = ['Dark Phoenix', 'Valerian and the City of a Thousand Planets', 'Jupiter Ascending', 'Tomorrowland', 'Blade Runner 2049', 'Pacific Rim', 'Solo: A Star Wars Story', 'Rogue One: A Star Wars Story', 'Star Wars Ep. VII: The Force Awakens', 'Guardians of the Galaxy', 'Guardians of the Galaxy Vol 2', 'Star Trek Into Darkness', 'Star Trek Beyond', 'Pacific Rim: Uprising', 'Moonfall', 'Edge of Tomorrow', 'Justice League', 'The Great Wall', 'Independence Day: Resurgence', 'Alita: Battle Angel', 'War for the Planet of the Apes', 'Kong: Skull Island', 'The Meg', 'Man of Steel', 'World War Z', 'Transformers: The Last Knight', 'Mad Max: Fury Road', 'Terminator: Genisys', 'PokÃ©mon: Detective Pikachu', 'Godzilla: King of the Monsters', 'Godzilla', 'Dawn of the Planet of the Apes', 'Jurassic World', 'Jurassic World: Fallen Kingdom', 'Inception', 'Iron Man 3', 'Thor: The Dark World', 'Thor: Ragnarok', 'Star Wars Ep. VIII: The Last Jedi', 'Star Wars Ep. VIII: The Last Jedi', 'Interstellar', 'Iron Man 2']

# %%
scifi_list = np.where(df_highbudget['movie'].isin(sf_movies), 'r', 'b')

# %%
df_highbudget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 2 to 194
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 99 non-null     int64
#  1   release_date       99 non-null     object
#  2   movie              99 non-null     object
#  3   production_budget  99 non-null     int64
#  4   domestic_gross     99 non-null     int64
#  5   worldwide_gross    99 non-null     int64
#  6   total_profit       99 non-null     int64
#  7   year               99 non-null     int64
#  8   ROI %              99 non-null     float64
#  9   is_sci-fi          99 non-null     bool
# dtypes: bool(1), float64(1), int64(6), object(2)
# memory usage: 7.8+ KB

# %%
import seaborn as sns

sns.regplot(df_highbudget['production_budget'], df_highbudget['ROI %'])
# Out:
# /Users/dillmedd/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='production_budget', ylabel='ROI %'>

# %%
df_highbudget.sort_values(by=['ROI %']).head(35)
# Out:
#      id  release_date                                        movie  \
# 194  95  Dec 31, 2020                                     Moonfall
# 2     3   Jun 7, 2019                                 Dark Phoenix
# 146  47  Sep 30, 2016                            Deepwater Horizon
# 110  11  May 12, 2017             King Arthur: Legend of the Sword
# 111  12  Dec 25, 2013                                     47 Ronin
# 12   13   Jul 2, 2013                              The Lone Ranger
# 192  93   Oct 9, 2015                                          Pan
# 65   66   Mar 1, 2013                        Jack the Giant Slayer
# 90   91   Feb 6, 2015                            Jupiter Ascending
# 89   90  Jul 21, 2017  Valerian and the City of a Thousand Planets
# 122  23  May 22, 2015                                 Tomorrowland
# 189  90  Jun 28, 2013                             White House Down
# 79   80   Oct 6, 2017                            Blade Runner 2049
# 11   12  May 25, 2018                      Solo: A Star Wars Story
# 125  26  May 27, 2016              Alice Through the Looking Glass
# 124  25  May 31, 2019               Godzilla: King of the Monsters
# 72   73  Nov 25, 2015                            The Good Dinosaur
# 78   79  Jul 22, 2016                             Star Trek Beyond
# 69   70  May 10, 2013                             The Great Gatsby
# 149  50  Mar 23, 2018                        Pacific Rim: Uprising
# 8    118.648403      False
# 104  119.166497      False
# 191  122.991235      False
# 132  132.829954      False
# 123  137.044727      False
# 53   145.179525      False
# 67   145.990307      False
# 174  146.732013      False
# 145  165.951426      False
# 175  174.172289      False

# %%
df_highbudget['movie'].tolist()
# Out:
# ['Dark Phoenix',
#  'Avengers: Age of Ultron',
#  'Star Wars Ep. VIII: The Last Jedi',
#  'Star Wars Ep. VII: The Force Awakens',
#  'Avengers: Infinity War',
#  'Justice League',
#  'Spectre',
#  'Solo: A Star Wars Story',
#  'The Lone Ranger',
#  'Captain America: Civil War',
#  'Batman v Superman: Dawn of Justice',
#  'The Hobbit: The Desolation of Smaug',
#  'The Hobbit: The Battle of the Five Armies',
#  'The Fate of the Furious',
#  'Pirates of the Caribbean: Dead Men Tell No Tales',
#  'Man of Steel',
#  'Transformers: The Last Knight',
#  'Jurassic World',
#  'Transformers: Age of Extinction',
#  'Black Panther',
#  'Incredibles 2',
#  'Rogue One: A Star Wars Story',
#  'Finding Dory',
#  'Iron Man 3',
#  'Guardians of the Galaxy Vol 2',
#  'Monsters University',
#  'Oz the Great and Powerful',
#  'X-Men: Days of Future Past',
#  'The Amazing Spider-Man 2',
#  'Fantastic Beasts: The Crimes of Grindelwald',
#  'The Mummy',
#  'Jack the Giant Slayer',
#  'Furious 7',
#  'Star Trek Into Darkness',
#  'World War Z',
#  'The Great Gatsby',
#  'Pacific Rim',
#  'The Good Dinosaur',
#  'Kong: Skull Island',
#  'Star Trek Beyond',
#  'Blade Runner 2049',
#  'Aladdin',
#  'Thor: Ragnarok',
#  'Maleficent',
#  'Fantastic Beasts and Where to Find Them',
#  'The Legend of Tarzan',
#  'Valerian and the City of a Thousand Planets',
#  'Jupiter Ascending',
#  'Mission: Impossibleâ\x80\x94Fallout',
#  'X-Men: Apocalypse',
#  'The Meg',
#  'Edge of Tomorrow',
#  'Captain Marvel',
#  'The Jungle Book',
#  'Inside Out',
#  'Spider-Man: Homecoming',
#  'Suicide Squad',
#  'Coco',
#  'Ralph Breaks The Internet',
#  'Cars 3',
#  'King Arthur: Legend of the Sword',
#  '47 Ronin',
#  'Jurassic World: Fallen Kingdom',
#  'Guardians of the Galaxy',
#  'Captain America: The Winter Soldier',
#  'Dawn of the Planet of the Apes',
#  'Dumbo',
#  'Tomorrowland',
#  'Alita: Battle Angel',
#  'Godzilla: King of the Monsters',
#  'Alice Through the Looking Glass',
#  'Doctor Strange',
#  'Big Hero 6',
#  'Interstellar',
#  'Independence Day: Resurgence',
#  'Beauty and the Beast',
#  'Aquaman',
#  'The Hunger Games: Mockingjay - Part 2',
#  'Fast and Furious 6',
#  'Godzilla',
#  'Warcraft',
#  'Deepwater Horizon',
#  'Terminator: Genisys',
#  'Pacific Rim: Uprising',
#  'War for the Planet of the Apes',
#  'Wonder Woman',
#  'Frozen',
#  'Zootopia',
#  'Moana',
#  'Thor: The Dark World',
#  'Mission: Impossibleâ\x80\x94Rogue Nation',
#  'Dunkirk',
#  'Mad Max: Fury Road',
#  'PokÃ©mon: Detective Pikachu',
#  'Ready Player One',
#  'White House Down',
#  'The Great Wall',
#  'Pan',
#  'Moonfall']

# %%
fig, ax = plt.subplots(figsize = (8, 8))

plt.scatter(df_highbudget['production_budget'], df_highbudget['ROI %'], c = scifi_list)
plt.xlabel('Budget (in 100s of millions)')
plt.ylabel('ROI %')
plt.axhline(y=0, color='r', linestyle='-')
plt.axhline(y=250, color='g', linestyle='-');

# %%
# 27/41 sci-fi films did not reach 2.5x goal (typical marker for box office success)
# Films that were marked as successful were 2 of the Jurassic Park movies, 3 Star wars movies, 2 transformers,
# 2 thor moves, Iron man 2 and 3, Guardians of the galaxy (1 and 2), Dawn of planet of the apes, 
#Interstellar and Inception
#of the 14 successful, 12 were parts of already successful movies series, the other two were high rated, oscar winning films

# %%
df_medbudget.sort_values(by=['ROI %'], ascending = False).head(50)
# Out:
#      id  release_date                                          movie  \
# 437  38  Dec 20, 2017                 Jumanji: Welcome to the Jungle
# 302   3   Oct 5, 2018                                          Venom
# 314  15  May 18, 2018                                     Deadpool 2
# 237  38  Nov 22, 2013                The Hunger Games: Catching Fire
# 315  16   Oct 4, 2013                                        Gravity
# 261  62  Nov 21, 2014          The Hunger Games: Mockingjay - Part 1
# 345  46   Oct 2, 2015                                    The Martian
# 412  13  Mar 13, 2015                                     Cinderella
# 258  59   Mar 3, 2017                                          Logan
# 240  41   Jul 6, 2018                           Ant-Man and the Wasp
# 361  62  Dec 21, 2018                                      Bumblebee
# 428  29  Feb 13, 2015                   Kingsman: The Secret Service
# 225  26  Mar 22, 2013                                     The Croods
# 198  99  Jun 13, 2014                     How to Train Your Dragon 2
# 443  44  Dec 14, 2018           Spider-Man: Into The Spider-Verse 3D
# 318  19  May 29, 2015                                    San Andreas
# 270  71  Mar 31, 2017                                  The Boss Baby
# 255  56  Feb 22, 2019     How to Train Your Dragon: The Hidden World
# 242  43  Jul 17, 2015                                        Ant-Man
# 226  27  Dec 25, 2015                                   The Revenant
# 353  54  Sep 22, 2017                    Kingsman: The Golden Circle
# 375  76  Dec 25, 2013                        The Wolf of Wall Street
# 267  68   Aug 8, 2014                   Teenage Mutant Ninja Turtles
# 351  52  Jul 22, 2016                      Ice Age: Collision Course
# 248  49  Apr 11, 2014                                          Rio 2
# 210  11  Jan 29, 2016                                Kung Fu Panda 3
# 465  66  Jun 10, 2016                               Now You See Me 2
# 307   8  Jul 26, 2013                                  The Wolverine
# 289  90  Apr 13, 2018                                        Rampage
# 356  57  May 23, 2013                                 The Hangover 3
# 285  86  Jul 29, 2016                                   Jason Bourne
# 433  34  Feb 14, 2013                         A Good Day to Die Hard
# 332  33  Jul 31, 2013                                   The Smurfs 2
# 469  70  Mar 16, 2018                                    Tomb Raider
# 325  26   Mar 7, 2014                         300: Rise of an Empire
# 243  44  Mar 27, 2015                                           Home
# 259  60  Dec 19, 2014        Night at the Museum: Secret of the Tomb
# 236  37  Nov 26, 2014                         Penguins of Madagascar
# 455  56  Dec 18, 2015         Alvin and the Chipmunks: The Road Chip
# 272  73   Nov 4, 2016                                         Trolls
# 327  28  Dec 21, 2016                                     Passengers
# 250  51  Mar 28, 2014                                           Noah
# 443  317.090853
# 318  314.780490
# 270  308.703010
# 255  302.525801
# 242  299.121884
# 226  294.769113
# 353  293.080477
# 375  289.870414
# 267  288.003803
# 351  283.006364
# 248  279.112532
# 210  269.713673
# 465  264.805563
# 307  262.136393
# 289  256.713567
# 356  251.456381
# 285  246.806930
# 433  230.705650
# 332  216.861385
# 469  203.863890
# 325  200.709137
# 243  196.921458
# 259  178.548520
# 236  177.986766
# 455  177.242173
# 272  175.320107
# 327  174.763338
# 250  171.408512
# 458  171.157560
# 329  169.078978
# 212  168.386218
# 321  168.250802
# 376  162.794441
# 244  162.714245
# 313  161.124261
# 406  152.617788

# %%
fig, ax = plt.subplots(figsize = (8, 8))

plt.scatter(df_medbudget['production_budget'], df_medbudget['ROI %'])
plt.xlabel('Budget (in 100s of millions)')
plt.ylabel('ROI %')
plt.axhline(y=0, color='r', linestyle='-')
plt.axhline(y=250, color='g', linestyle='-')

# %%
fig, ax = plt.subplots(figsize = (8, 8))

plt.scatter(df_lowerbudget['production_budget'], df_lowerbudget['ROI %'])
plt.xlabel('Budget (in 100s of millions)')
plt.ylabel('ROI %')
plt.axhline(y=0, color='r', linestyle='-')
plt.axhline(y=200, color='g', linestyle='-')

# %%
df_lowerbudget.sort_values(by=['ROI %'], ascending = False).head(50)
# Out:
#       id  release_date                                     movie  \
# 983   84   Nov 2, 2018                         Bohemian Rhapsody
# 672   73  Jul 10, 2015                                   Minions
# 1377  78  Feb 13, 2015                      Fifty Shades of Grey
# 955   56  Feb 12, 2016                                  Deadpool
# 629   30  Jun 30, 2017                           Despicable Me 3
# 621   22   Jul 3, 2013                           Despicable Me 2
# 625   26   Jul 8, 2016                   The Secret Life of Pets
# 1382  83  Jul 25, 2014                                      Lucy
# 956   57  Dec 25, 2014                           American Sniper
# 841   42  Feb 19, 2016                                Mei Ren Yu
# 628   29  Dec 21, 2016                                      Sing
# 776   77  Jul 13, 2018     Hotel Transylvania 3: Summer Vacation
# 1483  84  Jan 27, 2017          Resident Evil: The Final Chapter
# 1389  90  Jun 10, 2016  The Conjuring 2: The Enfield Poltergeist
# 843   44   Feb 7, 2014                            The Lego Movie
# 1096  97   Feb 9, 2018                              Peter Rabbit
# 990   91  Feb 10, 2017                       Fifty Shades Darker
# 1217  18   Jan 9, 2015                                   Taken 3
# 627   28   Nov 9, 2018                   Dr. Seussâ The Grinch
# 996   97   Feb 9, 2018                        Fifty Shades Freed
# 1084  85  Jun 13, 2014                            22 Jump Street
# 1379  80  Dec 13, 2013                           American Hustle
# 980   81  Jan 22, 2016                               Zhuo yao ji
# 1380  81  May 17, 2019       John Wick: Chapter 3 â Parabellum
# 994   95  Nov 10, 2017              Murder on the Orient Express
# 835   36   Oct 3, 2014                                 Gone Girl
# 541   42  Sep 25, 2015                      Hotel Transylvania 2
# 1334  35  Jun 28, 2013                                  The Heat
# 837   38  Sep 18, 2015            Maze Runner: The Scorch Trials
# 1405   6  Sep 25, 2015                                The Intern
# 1401   2  Apr 25, 2014                           The Other Woman
